# %%
#import libraries
import pandas as pd
import json
import requests
import matplotlib
from pprint import pprint
from datetime import datetime, timedelta
import os
import csv

# %%
# url for GET requests to retrieve vaccination data
url="https://data.cdc.gov/resource/unsk-b7fc.json"
#query_url="https://data.cdc.gov/resource/unsk-b7fc.json?$where=date between '2022-01-01T00:00:00.000' and '2022-12-31T23:59:59.999'"
query_url="https://data.cdc.gov/resource/unsk-b7fc.json?$query=SELECT%0A%20%20%60date%60%2C%0A%20%20%60mmwr_week%60%2C%0A%20%20%60location%60%2C%0A%20%20%60distributed%60%2C%0A%20%20%60distributed_janssen%60%2C%0A%20%20%60distributed_moderna%60%2C%0A%20%20%60distributed_pfizer%60%2C%0A%20%20%60distributed_novavax%60%2C%0A%20%20%60distributed_unk_manuf%60%2C%0A%20%20%60dist_per_100k%60%2C%0A%20%20%60distributed_per_100k_5plus%60%2C%0A%20%20%60distributed_per_100k_12plus%60%2C%0A%20%20%60distributed_per_100k_18plus%60%2C%0A%20%20%60distributed_per_100k_65plus%60%2C%0A%20%20%60administered%60%2C%0A%20%20%60administered_5plus%60%2C%0A%20%20%60administered_12plus%60%2C%0A%20%20%60administered_18plus%60%2C%0A%20%20%60administered_65plus%60%2C%0A%20%20%60administered_janssen%60%2C%0A%20%20%60administered_moderna%60%2C%0A%20%20%60administered_pfizer%60%2C%0A%20%20%60administered_novavax%60%2C%0A%20%20%60administered_unk_manuf%60%2C%0A%20%20%60admin_per_100k%60%2C%0A%20%20%60admin_per_100k_5plus%60%2C%0A%20%20%60admin_per_100k_12plus%60%2C%0A%20%20%60admin_per_100k_18plus%60%2C%0A%20%20%60admin_per_100k_65plus%60%2C%0A%20%20%60recip_administered%60%2C%0A%20%20%60administered_dose1_recip%60%2C%0A%20%20%60administered_dose1_pop_pct%60%2C%0A%20%20%60administered_dose1_recip_5plus%60%2C%0A%20%20%60administered_dose1_recip_5pluspop_pct%60%2C%0A%20%20%60administered_dose1_recip_12plus%60%2C%0A%20%20%60administered_dose1_recip_12pluspop_pct%60%2C%0A%20%20%60administered_dose1_recip_18plus%60%2C%0A%20%20%60administered_dose1_recip_18pluspop_pct%60%2C%0A%20%20%60administered_dose1_recip_65plus%60%2C%0A%20%20%60administered_dose1_recip_65pluspop_pct%60%2C%0A%20%20%60series_complete_yes%60%2C%0A%20%20%60series_complete_pop_pct%60%2C%0A%20%20%60series_complete_5plus%60%2C%0A%20%20%60series_complete_5pluspop_pct%60%2C%0A%20%20%60series_complete_12plus%60%2C%0A%20%20%60series_complete_12pluspop%60%2C%0A%20%20%60series_complete_18plus%60%2C%0A%20%20%60series_complete_18pluspop%60%2C%0A%20%20%60series_complete_65plus%60%2C%0A%20%20%60series_complete_65pluspop%60%2C%0A%20%20%60series_complete_janssen%60%2C%0A%20%20%60series_complete_moderna%60%2C%0A%20%20%60series_complete_pfizer%60%2C%0A%20%20%60series_complete_novavax%60%2C%0A%20%20%60series_complete_unk_manuf%60%2C%0A%20%20%60series_complete_janssen_5plus%60%2C%0A%20%20%60series_complete_moderna_5plus%60%2C%0A%20%20%60series_complete_pfizer_5plus%60%2C%0A%20%20%60series_complete_unk_manuf_5plus%60%2C%0A%20%20%60series_complete_janssen_12plus%60%2C%0A%20%20%60series_complete_moderna_12plus%60%2C%0A%20%20%60series_complete_pfizer_12plus%60%2C%0A%20%20%60series_complete_unk_manuf_1%60%2C%0A%20%20%60series_complete_janssen_18plus%60%2C%0A%20%20%60series_complete_moderna_18plus%60%2C%0A%20%20%60series_complete_pfizer_18plus%60%2C%0A%20%20%60series_complete_unk_manuf_2%60%2C%0A%20%20%60series_complete_janssen_65plus%60%2C%0A%20%20%60series_complete_moderna_65plus%60%2C%0A%20%20%60series_complete_pfizer_65plus%60%2C%0A%20%20%60series_complete_unk_manuf_3%60%2C%0A%20%20%60additional_doses%60%2C%0A%20%20%60additional_doses_vax_pct%60%2C%0A%20%20%60additional_doses_5plus%60%2C%0A%20%20%60additional_doses_5plus_vax_pct%60%2C%0A%20%20%60additional_doses_12plus%60%2C%0A%20%20%60additional_doses_12plus_vax_pct%60%2C%0A%20%20%60additional_doses_18plus%60%2C%0A%20%20%60additional_doses_18plus_vax_pct%60%2C%0A%20%20%60additional_doses_50plus%60%2C%0A%20%20%60additional_doses_50plus_vax_pct%60%2C%0A%20%20%60additional_doses_65plus%60%2C%0A%20%20%60additional_doses_65plus_vax_pct%60%2C%0A%20%20%60additional_doses_moderna%60%2C%0A%20%20%60additional_doses_pfizer%60%2C%0A%20%20%60additional_doses_janssen%60%2C%0A%20%20%60additional_doses_unk_manuf%60%2C%0A%20%20%60second_booster%60%2C%0A%20%20%60second_booster_50plus%60%2C%0A%20%20%60second_booster_50plus_vax_pct%60%2C%0A%20%20%60second_booster_65plus%60%2C%0A%20%20%60second_booster_65plus_vax_pct%60%2C%0A%20%20%60second_booster_janssen%60%2C%0A%20%20%60second_booster_moderna%60%2C%0A%20%20%60second_booster_pfizer%60%2C%0A%20%20%60second_booster_unk_manuf%60%2C%0A%20%20%60administered_bivalent%60%2C%0A%20%20%60admin_bivalent_pfr%60%2C%0A%20%20%60admin_bivalent_mod%60%2C%0A%20%20%60dist_bivalent_pfr%60%2C%0A%20%20%60dist_bivalent_mod%60%2C%0A%20%20%60bivalent_booster_5plus%60%2C%0A%20%20%60bivalent_booster_5plus_pop_pct%60%2C%0A%20%20%60bivalent_booster_12plus%60%2C%0A%20%20%60bivalent_booster_12plus_pop_pct%60%2C%0A%20%20%60bivalent_booster_18plus%60%2C%0A%20%20%60bivalent_booster_18plus_pop_pct%60%2C%0A%20%20%60bivalent_booster_65plus%60%2C%0A%20%20%60bivalent_booster_65plus_pop_pct%60%0AWHERE%0A%20%20%60date%60%0A%20%20%20%20BETWEEN%20%222022-01-01T00%3A00%3A00%22%20%3A%3A%20floating_timestamp%0A%20%20%20%20AND%20%222022-12-31T23%3A45%3A00%22%20%3A%3A%20floating_timestamp%0AORDER%20BY%20%60date%60%20ASC%20NULL%20LAST"

# %%
#print the response object to the console
print(requests.get(query_url))
# Out:
# <Response [200]>

# %%
#pretty print the output of json
response=requests.get(query_url).json()
#print(json.dumps(response,indent=4, sort_keys=True))
pprint(response)
# Out:
# [{'additional_doses': '734754',
#   'additional_doses_18plus': '731287',
#   'additional_doses_18plus_vax_pct': '33.2',
#   'additional_doses_50plus': '559008',
#   'additional_doses_50plus_vax_pct': '44.9',
#   'additional_doses_65plus': '350338',
#   'additional_doses_65plus_vax_pct': '55.7',
#   'additional_doses_janssen': '9900',
#   'additional_doses_moderna': '321754',
#   'additional_doses_pfizer': '403071',
#   'additional_doses_unk_manuf': '29',
#   'additional_doses_vax_pct': '31.4',
#   'admin_per_100k': '122002',
#   'admin_per_100k_12plus': '143161',
#   'admin_per_100k_18plus': '149706',
#   'admin_per_100k_5plus': '130457',
#   'admin_per_100k_65plus': '222922',
#   'administered': '5671632',
#   'administered_12plus': '5616645',
#   'administered_18plus': '5331274',
#   'administered_5plus': '5671379',
#   'administered_65plus': '1651898',
#   'administered_dose1_pop_pct': '57.6',
#   'administered_dose1_recip': '2677354',
#   'administered_dose1_recip_12plus': '2638402',
#   'administered_dose1_recip_12pluspop_pct': '67.2',
#   'administered_dose1_recip_18plus': '2481895',
#   'administered_dose1_recip_18pluspop_pct': '69.7',
#   'administered_dose1_recip_5plus': '2677154',
#   'administered_dose1_recip_5pluspop_pct': '61.6',
#   'administered_dose1_recip_65plus': '666173',
#   'administered_dose1_recip_65pluspop_pct': '89.9',
#   'administered_janssen': '186459',
#   'administered_moderna': '2340458',
#   'administered_pfizer': '3141846',
#   'administered_unk_manuf': '2869',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '147839',
#   'distributed': '6872750',
#   'distributed_janssen': '314500',
#   'distributed_moderna': '2558900',
#   'distributed_per_100k_12plus': '175177',
#   'distributed_per_100k_18plus': '192992',
#   'distributed_per_100k_5plus': '158091',
#   'distributed_per_100k_65plus': '927469',
#   'distributed_pfizer': '3999350',
#   'distributed_unk_manuf': '0',
#   'location': 'LA',
#   'mmwr_week': '52',
#   'recip_administered': '5612212',
#   'series_complete_12plus': '2325441',
#   'series_complete_12pluspop': '59.3',
#   'series_complete_18plus': '2199609',
#   'series_complete_18pluspop': '61.8',
#   'series_complete_5plus': '2341953',
#   'series_complete_5pluspop_pct': '53.9',
#   'series_complete_65plus': '629064',
#   'series_complete_65pluspop': '84.9',
#   'series_complete_janssen': '169481',
#   'series_complete_janssen_12plus': '169454',
#   'series_complete_janssen_18plus': '169297',
#   'series_complete_janssen_5plus': '169461',
#   'series_complete_janssen_65plus': '22148',
#   'series_complete_moderna': '926997',
#   'series_complete_moderna_12plus': '926971',
#   'series_complete_moderna_18plus': '926481',
#   'series_complete_moderna_5plus': '926983',
#   'series_complete_moderna_65plus': '298914',
#   'series_complete_pfizer': '1244508',
#   'series_complete_pfizer_12plus': '1227995',
#   'series_complete_pfizer_18plus': '1102821',
#   'series_complete_pfizer_5plus': '1244485',
#   'series_complete_pfizer_65plus': '307794',
#   'series_complete_pop_pct': '50.4',
#   'series_complete_unk_manuf': '1024',
#   'series_complete_unk_manuf_1': '1021',
#   'series_complete_unk_manuf_2': '1010',
#   'series_complete_unk_manuf_3': '208',
#   'series_complete_unk_manuf_5plus': '1024',
#   'series_complete_yes': '2342010'},
#  {'additional_doses': '561913',
#   'additional_doses_18plus': '557370',
#   'additional_doses_18plus_vax_pct': '36.8',
#   'additional_doses_50plus': '394213',
#   'additional_doses_50plus_vax_pct': '48.5',
#   'additional_doses_65plus': '244567',
#   'additional_doses_65plus_vax_pct': '58.3',
#   'additional_doses_janssen': '8186',
#   'additional_doses_moderna': '251525',
#   'additional_doses_pfizer': '302076',
#   'additional_doses_unk_manuf': '126',
#   'additional_doses_vax_pct': '33.8',
#   'admin_per_100k': '140268',
#   'admin_per_100k_12plus': '162873',
#   'admin_per_100k_18plus': '169027',
#   'admin_per_100k_5plus': '149793',
#   'admin_per_100k_65plus': '242000',
#   'administered': '4086457',
#   'administered_12plus': '3993155',
#   'administered_18plus': '3740686',
#   'administered_5plus': '4086325',
#   'administered_65plus': '1150678',
#   'administered_dose1_pop_pct': '69.4',
#   'administered_dose1_recip': '2022681',
#   'administered_dose1_recip_12plus': '1964326',
#   'administered_dose1_recip_12pluspop_pct': '80.1',
#   'administered_dose1_recip_18plus': '1830255',
#   'administered_dose1_recip_18pluspop_pct': '82.7',
#   'administered_dose1_recip_5plus': '2022559',
#   'administered_dose1_recip_5pluspop_pct': '74.1',
#   'administered_dose1_recip_65plus': '515090',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '128349',
#   'administered_moderna': '1577119',
#   'administered_pfizer': '2377622',
#   'administered_unk_manuf': '3367',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '178171',
#   'distributed': '5190675',
#   'distributed_janssen': '249000',
#   'distributed_moderna': '1942240',
#   'distributed_per_100k_12plus': '211718',
#   'distributed_per_100k_18plus': '234547',
#   'distributed_per_100k_5plus': '190275',
#   'distributed_per_100k_65plus': '1091650',
#   'distributed_pfizer': '2999435',
#   'distributed_unk_manuf': '0',
#   'location': 'KS',
#   'mmwr_week': '52',
#   'recip_administered': '4184654',
#   'series_complete_12plus': '1627822',
#   'series_complete_12pluspop': '66.4',
#   'series_complete_18plus': '1515265',
#   'series_complete_18pluspop': '68.5',
#   'series_complete_5plus': '1663064',
#   'series_complete_5pluspop_pct': '61',
#   'series_complete_65plus': '419510',
#   'series_complete_65pluspop': '88.2',
#   'series_complete_janssen': '117977',
#   'series_complete_janssen_12plus': '117957',
#   'series_complete_janssen_18plus': '117849',
#   'series_complete_janssen_5plus': '117972',
#   'series_complete_janssen_65plus': '18162',
#   'series_complete_moderna': '606789',
#   'series_complete_moderna_12plus': '606773',
#   'series_complete_moderna_18plus': '606420',
#   'series_complete_moderna_5plus': '606781',
#   'series_complete_moderna_65plus': '199737',
#   'series_complete_pfizer': '937706',
#   'series_complete_pfizer_12plus': '902485',
#   'series_complete_pfizer_18plus': '790464',
#   'series_complete_pfizer_5plus': '937700',
#   'series_complete_pfizer_65plus': '201359',
#   'series_complete_pop_pct': '57.1',
#   'series_complete_unk_manuf': '611',
#   'series_complete_unk_manuf_1': '607',
#   'series_complete_unk_manuf_2': '532',
#   'series_complete_unk_manuf_3': '252',
#   'series_complete_unk_manuf_5plus': '611',
#   'series_complete_yes': '1663083'},
#  {'additional_doses': '1106555',
#   'additional_doses_18plus': '1098338',
#   'additional_doses_18plus_vax_pct': '42.9',
#   'additional_doses_50plus': '727525',
#   'additional_doses_50plus_vax_pct': '55.9',
#   'additional_doses_65plus': '455089',
#   'additional_doses_65plus_vax_pct': '66.6',
#   'additional_doses_janssen': '17314',
#   'additional_doses_moderna': '486513',
#   'additional_doses_pfizer': '602397',
#   'additional_doses_unk_manuf': '331',
#   'additional_doses_vax_pct': '39.4',
#   'admin_per_100k': '162471',
#   'admin_per_100k_12plus': '183099',
#   'admin_per_100k_18plus': '187878',
#   'admin_per_100k_5plus': '171747',
#   'admin_per_100k_65plus': '239739',
#   'administered': '6852601',
#   'administered_12plus': '6679023',
#   'administered_18plus': '6296120',
#   'administered_5plus': '6852585',
#   'administered_65plus': '1836594',
#   'administered_dose1_pop_pct': '74.1',
#   'administered_dose1_recip': '3125992',
#   'administered_dose1_recip_12plus': '3023540',
#   'administered_dose1_recip_12pluspop_pct': '82.9',
#   'administered_dose1_recip_18plus': '2827038',
#   'administered_dose1_recip_18pluspop_pct': '84.4',
#   'administered_dose1_recip_5plus': '3125976',
#   'administered_dose1_recip_5pluspop_pct': '78.3',
#   'administered_dose1_recip_65plus': '740242',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '261026',
#   'administered_moderna': '2573078',
#   'administered_pfizer': '4007190',
#   'administered_unk_manuf': '11307',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '200998',
#   'distributed': '8477585',
#   'distributed_janssen': '452300',
#   'distributed_moderna': '3124020',
#   'distributed_per_100k_12plus': '232405',
#   'distributed_per_100k_18plus': '252974',
#   'distributed_per_100k_5plus': '212475',
#   'distributed_per_100k_65plus': '1106620',
#   'distributed_pfizer': '4901265',
#   'distributed_unk_manuf': '0',
#   'location': 'OR',
#   'mmwr_week': '52',
#   'recip_administered': '6848651',
#   'series_complete_12plus': '2736042',
#   'series_complete_12pluspop': '75',
#   'series_complete_18plus': '2559624',
#   'series_complete_18pluspop': '76.4',
#   'series_complete_5plus': '2805571',
#   'series_complete_5pluspop_pct': '70.3',
#   'series_complete_65plus': '683602',
#   'series_complete_65pluspop': '89.2',
#   'series_complete_janssen': '239114',
#   'series_complete_janssen_12plus': '239111',
#   'series_complete_janssen_18plus': '238292',
#   'series_complete_janssen_5plus': '239113',
#   'series_complete_janssen_65plus': '51925',
#   'series_complete_moderna': '975436',
#   'series_complete_moderna_12plus': '975432',
#   'series_complete_moderna_18plus': '972556',
#   'series_complete_moderna_5plus': '975435',
#   'series_complete_moderna_65plus': '308826',
#   'series_complete_pfizer': '1587331',
#   'series_complete_pfizer_12plus': '1517807',
#   'series_complete_pfizer_18plus': '1345233',
#   'series_complete_pfizer_5plus': '1587326',
#   'series_complete_pfizer_65plus': '321767',
#   'series_complete_pop_pct': '66.5',
#   'series_complete_unk_manuf': '3697',
#   'series_complete_unk_manuf_1': '3692',
#   'series_complete_unk_manuf_2': '3543',
#   'series_complete_unk_manuf_3': '1084',
#   'series_complete_unk_manuf_5plus': '3697',
#   'series_complete_yes': '2805578'},
#  {'additional_doses': '1100783',
#   'additional_doses_18plus': '1095320',
#   'additional_doses_18plus_vax_pct': '36.4',
#   'additional_doses_50plus': '802774',
#   'additional_doses_50plus_vax_pct': '47.5',
#   'additional_doses_65plus': '508817',
#   'additional_doses_65plus_vax_pct': '58.1',
#   'additional_doses_janssen': '13788',
#   'additional_doses_moderna': '458894',
#   'additional_doses_pfizer': '628057',
#   'additional_doses_unk_manuf': '44',
#   'additional_doses_vax_pct': '33.8',
#   'admin_per_100k': '132154',
#   'admin_per_100k_12plus': '151883',
#   'admin_per_100k_18plus': '157953',
#   'admin_per_100k_5plus': '140579',
#   'admin_per_100k_65plus': '224833',
#   'administered': '8110832',
#   'administered_12plus': '7952184',
#   'administered_18plus': '7529353',
#   'administered_5plus': '8110499',
#   'administered_65plus': '2387811',
#   'administered_dose1_pop_pct': '62.4',
#   'administered_dose1_recip': '3832565',
#   'administered_dose1_recip_12plus': '3735878',
#   'administered_dose1_recip_12pluspop_pct': '71.4',
#   'administered_dose1_recip_18plus': '3511271',
#   'administered_dose1_recip_18pluspop_pct': '73.7',
#   'administered_dose1_recip_5plus': '3832256',
#   'administered_dose1_recip_5pluspop_pct': '66.4',
#   'administered_dose1_recip_65plus': '995749',
#   'administered_dose1_recip_65pluspop_pct': '93.8',
#   'administered_janssen': '239492',
#   'administered_moderna': '2955042',
#   'administered_pfizer': '4913990',
#   'administered_unk_manuf': '2308',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '161109',
#   'distributed': '9887935',
#   'distributed_janssen': '410500',
#   'distributed_moderna': '3526700',
#   'distributed_per_100k_12plus': '188855',
#   'distributed_per_100k_18plus': '207432',
#   'distributed_per_100k_5plus': '171387',
#   'distributed_per_100k_65plus': '931035',
#   'distributed_pfizer': '5950735',
#   'distributed_unk_manuf': '0',
#   'location': 'MO',
#   'mmwr_week': '52',
#   'recip_administered': '8033561',
#   'series_complete_12plus': '3196985',
#   'series_complete_12pluspop': '61.1',
#   'series_complete_18plus': '3006631',
#   'series_complete_18pluspop': '63.1',
#   'series_complete_5plus': '3258046',
#   'series_complete_5pluspop_pct': '56.5',
#   'series_complete_65plus': '875038',
#   'series_complete_65pluspop': '82.4',
#   'series_complete_janssen': '228205',
#   'series_complete_janssen_12plus': '228179',
#   'series_complete_janssen_18plus': '227949',
#   'series_complete_janssen_5plus': '228189',
#   'series_complete_janssen_65plus': '39451',
#   'series_complete_moderna': '1124688',
#   'series_complete_moderna_12plus': '1124674',
#   'series_complete_moderna_18plus': '1124216',
#   'series_complete_moderna_5plus': '1124676',
#   'series_complete_moderna_65plus': '398537',
#   'series_complete_pfizer': '1904600',
#   'series_complete_pfizer_12plus': '1843550',
#   'series_complete_pfizer_18plus': '1654019',
#   'series_complete_pfizer_5plus': '1904591',
#   'series_complete_pfizer_65plus': '436889',
#   'series_complete_pop_pct': '53.1',
#   'series_complete_unk_manuf': '590',
#   'series_complete_unk_manuf_1': '582',
#   'series_complete_unk_manuf_2': '447',
#   'series_complete_unk_manuf_3': '161',
#   'series_complete_unk_manuf_5plus': '590',
#   'series_complete_yes': '3258083'},
#  {'additional_doses': '467495',
#   'additional_doses_18plus': '465439',
#   'additional_doses_18plus_vax_pct': '32.8',
#   'additional_doses_50plus': '351295',
#   'additional_doses_50plus_vax_pct': '44.3',
#   'additional_doses_65plus': '227236',
#   'additional_doses_65plus_vax_pct': '55.4',
#   'additional_doses_janssen': '7598',
#   'additional_doses_moderna': '229849',
#   'additional_doses_pfizer': '229647',
#   'additional_doses_unk_manuf': '401',
#   'additional_doses_vax_pct': '30.2',
#   'admin_per_100k': '125933',
#   'admin_per_100k_12plus': '145964',
#   'admin_per_100k_18plus': '151249',
#   'admin_per_100k_5plus': '134267',
#   'admin_per_100k_65plus': '211205',
#   'administered': '3800418',
#   'administered_12plus': '3732659',
#   'administered_18plus': '3505426',
#   'administered_5plus': '3798878',
#   'administered_65plus': '1106464',
#   'administered_dose1_pop_pct': '62.7',
#   'administered_dose1_recip': '1893069',
#   'administered_dose1_recip_12plus': '1848721',
#   'administered_dose1_recip_12pluspop_pct': '72.3',
#   'administered_dose1_recip_18plus': '1723920',
#   'administered_dose1_recip_18pluspop_pct': '74.4',
#   'administered_dose1_recip_5plus': '1891592',
#   'administered_dose1_recip_5pluspop_pct': '66.9',
#   'administered_dose1_recip_65plus': '485106',
#   'administered_dose1_recip_65pluspop_pct': '92.6',
#   'administered_janssen': '116704',
#   'administered_moderna': '1635366',
#   'administered_pfizer': '2044668',
#   'administered_unk_manuf': '3680',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '165324',
#   'distributed': '4989160',
#   'distributed_janssen': '247500',
#   'distributed_moderna': '1922840',
#   'distributed_per_100k_12plus': '195099',
#   'distributed_per_100k_18plus': '215268',
#   'distributed_per_100k_5plus': '176337',
#   'distributed_per_100k_65plus': '952344',
#   'distributed_pfizer': '2818820',
#   'distributed_unk_manuf': '0',
#   'location': 'AR',
#   'mmwr_week': '52',
#   'recip_administered': '3828976',
#   'series_complete_12plus': '1521996',
#   'series_complete_12pluspop': '59.5',
#   'series_complete_18plus': '1420760',
#   'series_complete_18pluspop': '61.3',
#   'series_complete_5plus': '1545415',
#   'series_complete_5pluspop_pct': '54.6',
#   'series_complete_65plus': '410235',
#   'series_complete_65pluspop': '78.3',
#   'series_complete_janssen': '108363',
#   'series_complete_janssen_12plus': '108239',
#   'series_complete_janssen_18plus': '107830',
#   'series_complete_janssen_5plus': '108246',
#   'series_complete_janssen_65plus': '15482',
#   'series_complete_moderna': '638111',
#   'series_complete_moderna_12plus': '638098',
#   'series_complete_moderna_18plus': '636980',
#   'series_complete_moderna_5plus': '638100',
#   'series_complete_moderna_65plus': '230214',
#   'series_complete_pfizer': '798038',
#   'series_complete_pfizer_12plus': '774820',
#   'series_complete_pfizer_18plus': '675147',
#   'series_complete_pfizer_5plus': '797995',
#   'series_complete_pfizer_65plus': '164087',
#   'series_complete_pop_pct': '51.2',
#   'series_complete_unk_manuf': '1075',
#   'series_complete_unk_manuf_1': '839',
#   'series_complete_unk_manuf_2': '803',
#   'series_complete_unk_manuf_3': '452',
#   'series_complete_unk_manuf_5plus': '1074',
#   'series_complete_yes': '1545587'},
#  {'additional_doses': '194156',
#   'additional_doses_18plus': '192495',
#   'additional_doses_18plus_vax_pct': '26.3',
#   'additional_doses_50plus': '124358',
#   'additional_doses_50plus_vax_pct': '35',
#   'additional_doses_65plus': '58858',
#   'additional_doses_65plus_vax_pct': '43',
#   'additional_doses_janssen': '1181',
#   'additional_doses_moderna': '95605',
#   'additional_doses_pfizer': '97252',
#   'additional_doses_unk_manuf': '118',
#   'additional_doses_vax_pct': '23.7',
#   'admin_per_100k': '97430',
#   'admin_per_100k_12plus': '0',
#   'admin_per_100k_18plus': '0',
#   'admin_per_100k_5plus': '0',
#   'admin_per_100k_65plus': '0',
#   'administered': '2029277',
#   'administered_12plus': '1980058',
#   'administered_18plus': '1822541',
#   'administered_5plus': '2028793',
#   'administered_65plus': '371151',
#   'administered_dose1_pop_pct': '49.4',
#   'administered_dose1_recip': '1029452',
#   'administered_dose1_recip_12plus': '997826',
#   'administered_dose1_recip_12pluspop_pct': '0',
#   'administered_dose1_recip_18plus': '912150',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_5plus': '1029138',
#   'administered_dose1_recip_5pluspop_pct': '0',
#   'administered_dose1_recip_65plus': '172721',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'administered_janssen': '38028',
#   'administered_moderna': '969922',
#   'administered_pfizer': '1021159',
#   'administered_unk_manuf': '168',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '122060',
#   'distributed': '2542275',
#   'distributed_janssen': '101900',
#   'distributed_moderna': '1139460',
#   'distributed_per_100k_12plus': '0',
#   'distributed_per_100k_18plus': '0',
#   'distributed_per_100k_5plus': '0',
#   'distributed_per_100k_65plus': '0',
#   'distributed_pfizer': '1300915',
#   'distributed_unk_manuf': '0',
#   'location': 'IH2',
#   'mmwr_week': '52',
#   'recip_administered': '2029277',
#   'series_complete_12plus': '802971',
#   'series_complete_12pluspop': '0',
#   'series_complete_18plus': '733096',
#   'series_complete_18pluspop': '0',
#   'series_complete_5plus': '820351',
#   'series_complete_5pluspop_pct': '0',
#   'series_complete_65plus': '136744',
#   'series_complete_65pluspop': '0',
#   'series_complete_janssen': '36705',
#   'series_complete_janssen_12plus': '36682',
#   'series_complete_janssen_18plus': '36640',
#   'series_complete_janssen_5plus': '36683',
#   'series_complete_janssen_65plus': '3393',
#   'series_complete_moderna': '381057',
#   'series_complete_moderna_12plus': '380975',
#   'series_complete_moderna_18plus': '380730',
#   'series_complete_moderna_5plus': '380986',
#   'series_complete_moderna_65plus': '77039',
#   'series_complete_pfizer': '402728',
#   'series_complete_pfizer_12plus': '385308',
#   'series_complete_pfizer_18plus': '315720',
#   'series_complete_pfizer_5plus': '402676',
#   'series_complete_pfizer_65plus': '56311',
#   'series_complete_pop_pct': '39.4',
#   'series_complete_unk_manuf': '6',
#   'series_complete_unk_manuf_1': '6',
#   'series_complete_unk_manuf_2': '6',
#   'series_complete_unk_manuf_3': '1',
#   'series_complete_unk_manuf_5plus': '6',
#   'series_complete_yes': '820496'},
#  {'additional_doses': '872856',
#   'additional_doses_18plus': '868043',
#   'additional_doses_18plus_vax_pct': '38.7',
#   'additional_doses_50plus': '638057',
#   'additional_doses_50plus_vax_pct': '50.5',
#   'additional_doses_65plus': '386696',
#   'additional_doses_65plus_vax_pct': '61',
#   'additional_doses_janssen': '18684',
#   'additional_doses_moderna': '400527',
#   'additional_doses_pfizer': '453540',
#   'additional_doses_unk_manuf': '105',
#   'additional_doses_vax_pct': '36',
#   'admin_per_100k': '132506',
#   'admin_per_100k_12plus': '152627',
#   'admin_per_100k_18plus': '158914',
#   'admin_per_100k_5plus': '141091',
#   'admin_per_100k_65plus': '225457',
#   'administered': '5919915',
#   'administered_12plus': '5809221',
#   'administered_18plus': '5506056',
#   'administered_5plus': '5918850',
#   'administered_65plus': '1692198',
#   'administered_dose1_pop_pct': '62.6',
#   'administered_dose1_recip': '2797963',
#   'administered_dose1_recip_12plus': '2731214',
#   'administered_dose1_recip_12pluspop_pct': '71.8',
#   'administered_dose1_recip_18plus': '2570019',
#   'administered_dose1_recip_18pluspop_pct': '74.2',
#   'administered_dose1_recip_5plus': '2797615',
#   'administered_dose1_recip_5pluspop_pct': '66.7',
#   'administered_dose1_recip_65plus': '711412',
#   'administered_dose1_recip_65pluspop_pct': '94.8',
#   'administered_janssen': '224293',
#   'administered_moderna': '2454733',
#   'administered_pfizer': '3238776',
#   'administered_unk_manuf': '2113',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '166529',
#   'distributed': '7439965',
#   'distributed_janssen': '369000',
#   'distributed_moderna': '2930440',
#   'distributed_per_100k_12plus': '195471',
#   'distributed_per_100k_18plus': '214730',
#   'distributed_per_100k_5plus': '177350',
#   'distributed_per_100k_65plus': '991250',
#   'distributed_pfizer': '4140525',
#   'distributed_unk_manuf': '0',
#   'location': 'KY',
#   'mmwr_week': '52',
#   'recip_administered': '5949967',
#   'series_complete_12plus': '2383727',
#   'series_complete_12pluspop': '62.6',
#   'series_complete_18plus': '2245430',
#   'series_complete_18pluspop': '64.8',
#   'series_complete_5plus': '2427136',
#   'series_complete_5pluspop_pct': '57.9',
#   'series_complete_65plus': '634019',
#   'series_complete_65pluspop': '84.5',
#   'series_complete_janssen': '202850',
#   'series_complete_janssen_12plus': '202819',
#   'series_complete_janssen_18plus': '202706',
#   'series_complete_janssen_5plus': '202828',
#   'series_complete_janssen_65plus': '38216',
#   'series_complete_moderna': '942881',
#   'series_complete_moderna_12plus': '942780',
#   'series_complete_moderna_18plus': '942534',
#   'series_complete_moderna_5plus': '942872',
#   'series_complete_moderna_65plus': '289656',
#   'series_complete_pfizer': '1279867',
#   'series_complete_pfizer_12plus': '1236549',
#   'series_complete_pfizer_18plus': '1098682',
#   'series_complete_pfizer_5plus': '1279853',
#   'series_complete_pfizer_65plus': '305366',
#   'series_complete_pop_pct': '54.3',
#   'series_complete_unk_manuf': '1584',
#   'series_complete_unk_manuf_1': '1579',
#   'series_complete_unk_manuf_2': '1508',
#   'series_complete_unk_manuf_3': '781',
#   'series_complete_unk_manuf_5plus': '1583',
#   'series_complete_yes': '2427182'},
#  {'additional_doses': '13714',
#   'additional_doses_18plus': '13595',
#   'additional_doses_18plus_vax_pct': '42',
#   'additional_doses_50plus': '7194',
#   'additional_doses_50plus_vax_pct': '55.3',
#   'additional_doses_65plus': '1875',
#   'additional_doses_65plus_vax_pct': '62.4',
#   'additional_doses_janssen': '136',
#   'additional_doses_moderna': '2992',
#   'additional_doses_pfizer': '10586',
#   'additional_doses_unk_manuf': '0',
#   'additional_doses_vax_pct': '34.4',
#   'admin_per_100k': '184747',
#   'admin_per_100k_12plus': '211161',
#   'admin_per_100k_18plus': '219665',
#   'admin_per_100k_5plus': '199143',
#   'admin_per_100k_65plus': '210043',
#   'administered': '95793',
#   'administered_12plus': '89300',
#   'administered_18plus': '79244',
#   'administered_5plus': '95792',
#   'administered_65plus': '7885',
#   'administered_dose1_pop_pct': '83.6',
#   'administered_dose1_recip': '43361',
#   'administered_dose1_recip_12plus': '39576',
#   'administered_dose1_recip_12pluspop_pct': '93.6',
#   'administered_dose1_recip_18plus': '34411',
#   'administered_dose1_recip_18pluspop_pct': '95',
#   'administered_dose1_recip_5plus': '43360',
#   'administered_dose1_recip_5pluspop_pct': '90.1',
#   'administered_dose1_recip_65plus': '3129',
#   'administered_dose1_recip_65pluspop_pct': '83.4',
#   'administered_janssen': '1244',
#   'administered_moderna': '13235',
#   'administered_pfizer': '81314',
#   'administered_unk_manuf': '0',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '218569',
#   'distributed': '113330',
#   'distributed_janssen': '3300',
#   'distributed_moderna': '24720',
#   'distributed_per_100k_12plus': '267983',
#   'distributed_per_100k_18plus': '314151',
#   'distributed_per_100k_5plus': '235604',
#   'distributed_per_100k_65plus': '3018910',
#   'distributed_pfizer': '85310',
#   'distributed_unk_manuf': '0',
#   'location': 'MP',
#   'mmwr_week': '52',
#   'recip_administered': '95896',
#   'series_complete_12plus': '37173',
#   'series_complete_12pluspop': '87.9',
#   'series_complete_18plus': '32392',
#   'series_complete_18pluspop': '89.8',
#   'series_complete_5plus': '39878',
#   'series_complete_5pluspop_pct': '82.9',
#   'series_complete_65plus': '3004',
#   'series_complete_65pluspop': '80',
#   'series_complete_janssen': '1111',
#   'series_complete_janssen_12plus': '1111',
#   'series_complete_janssen_18plus': '1111',
#   'series_complete_janssen_5plus': '1111',
#   'series_complete_janssen_65plus': '114',
#   'series_complete_moderna': '4822',
#   'series_complete_moderna_12plus': '4822',
#   'series_complete_moderna_18plus': '4821',
#   'series_complete_moderna_5plus': '4822',
#   'series_complete_moderna_65plus': '476',
#   'series_complete_pfizer': '33945',
#   'series_complete_pfizer_12plus': '31240',
#   'series_complete_pfizer_18plus': '26460',
#   'series_complete_pfizer_5plus': '33945',
#   'series_complete_pfizer_65plus': '2414',
#   'series_complete_pop_pct': '76.9',
#   'series_complete_unk_manuf': '0',
#   'series_complete_unk_manuf_1': '0',
#   'series_complete_unk_manuf_2': '0',
#   'series_complete_unk_manuf_3': '0',
#   'series_complete_unk_manuf_5plus': '0',
#   'series_complete_yes': '39878'},
#  {'additional_doses': '870944',
#   'additional_doses_18plus': '866566',
#   'additional_doses_18plus_vax_pct': '33.9',
#   'additional_doses_50plus': '676511',
#   'additional_doses_50plus_vax_pct': '45',
#   'additional_doses_65plus': '441553',
#   'additional_doses_65plus_vax_pct': '55.3',
#   'additional_doses_janssen': '17370',
#   'additional_doses_moderna': '374743',
#   'additional_doses_pfizer': '478375',
#   'additional_doses_unk_manuf': '456',
#   'additional_doses_vax_pct': '31.8',
#   'admin_per_100k': '131135',
#   'admin_per_100k_12plus': '150573',
#   'admin_per_100k_18plus': '156622',
#   'admin_per_100k_5plus': '138998',
#   'admin_per_100k_65plus': '230117',
#   'administered': '6751786',
#   'administered_12plus': '6655297',
#   'administered_18plus': '6323645',
#   'administered_5plus': '6750089',
#   'administered_65plus': '2156252',
#   'administered_dose1_pop_pct': '63',
#   'administered_dose1_recip': '3242012',
#   'administered_dose1_recip_12plus': '3179634',
#   'administered_dose1_recip_12pluspop_pct': '71.9',
#   'administered_dose1_recip_18plus': '3000527',
#   'administered_dose1_recip_18pluspop_pct': '74.3',
#   'administered_dose1_recip_5plus': '3240870',
#   'administered_dose1_recip_5pluspop_pct': '66.7',
#   'administered_dose1_recip_65plus': '928715',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '217628',
#   'administered_moderna': '2655742',
#   'administered_pfizer': '3876368',
#   'administered_unk_manuf': '2048',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '171076',
#   'distributed': '8808215',
#   'distributed_janssen': '436400',
#   'distributed_moderna': '3433020',
#   'distributed_per_100k_12plus': '199282',
#   'distributed_per_100k_18plus': '218158',
#   'distributed_per_100k_5plus': '181379',
#   'distributed_per_100k_65plus': '940021',
#   'distributed_pfizer': '4938795',
#   'distributed_unk_manuf': '0',
#   'location': 'SC',
#   'mmwr_week': '52',
#   'recip_administered': '6724579',
#   'series_complete_12plus': '2704390',
#   'series_complete_12pluspop': '61.2',
#   'series_complete_18plus': '2553566',
#   'series_complete_18pluspop': '63.2',
#   'series_complete_5plus': '2740497',
#   'series_complete_5pluspop_pct': '56.4',
#   'series_complete_65plus': '798197',
#   'series_complete_65pluspop': '85.2',
#   'series_complete_janssen': '196953',
#   'series_complete_janssen_12plus': '196909',
#   'series_complete_janssen_18plus': '196355',
#   'series_complete_janssen_5plus': '196911',
#   'series_complete_janssen_65plus': '30563',
#   'series_complete_moderna': '1001070',
#   'series_complete_moderna_12plus': '1000957',
#   'series_complete_moderna_18plus': '999014',
#   'series_complete_moderna_5plus': '1000995',
#   'series_complete_moderna_65plus': '341196',
#   'series_complete_pfizer': '1542660',
#   'series_complete_pfizer_12plus': '1506175',
#   'series_complete_pfizer_18plus': '1357850',
#   'series_complete_pfizer_5plus': '1542242',
#   'series_complete_pfizer_65plus': '426234',
#   'series_complete_pop_pct': '53.2',
#   'series_complete_unk_manuf': '349',
#   'series_complete_unk_manuf_1': '349',
#   'series_complete_unk_manuf_2': '347',
#   'series_complete_unk_manuf_3': '204',
#   'series_complete_unk_manuf_5plus': '349',
#   'series_complete_yes': '2741032'},
#  {'additional_doses': '547206',
#   'additional_doses_18plus': '543653',
#   'additional_doses_18plus_vax_pct': '43.3',
#   'additional_doses_50plus': '369325',
#   'additional_doses_50plus_vax_pct': '54.9',
#   'additional_doses_65plus': '214697',
#   'additional_doses_65plus_vax_pct': '62.5',
#   'additional_doses_janssen': '7801',
#   'additional_doses_moderna': '233860',
#   'additional_doses_pfizer': '305464',
#   'additional_doses_unk_manuf': '81',
#   'additional_doses_vax_pct': '39.3',
#   'admin_per_100k': '164750',
#   'admin_per_100k_12plus': '188643',
#   'admin_per_100k_18plus': '194666',
#   'admin_per_100k_5plus': '174828',
#   'admin_per_100k_65plus': '245909',
#   'administered': '3454524',
#   'administered_12plus': '3371863',
#   'administered_18plus': '3155521',
#   'administered_5plus': '3454330',
#   'administered_65plus': '928567',
#   'administered_dose1_pop_pct': '80.9',
#   'administered_dose1_recip': '1696287',
#   'administered_dose1_recip_12plus': '1641371',
#   'administered_dose1_recip_12pluspop_pct': '91.8',
#   'administered_dose1_recip_18plus': '1517336',
#   'administered_dose1_recip_18pluspop_pct': '93.6',
#   'administered_dose1_recip_5plus': '1696111',
#   'administered_dose1_recip_5pluspop_pct': '85.8',
#   'administered_dose1_recip_65plus': '407918',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '111550',
#   'administered_moderna': '1420049',
#   'administered_pfizer': '1915679',
#   'administered_unk_manuf': '7246',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '180609',
#   'distributed': '3787065',
#   'distributed_janssen': '182900',
#   'distributed_moderna': '1435760',
#   'distributed_per_100k_12plus': '211872',
#   'distributed_per_100k_18plus': '233627',
#   'distributed_per_100k_5plus': '191668',
#   'distributed_per_100k_65plus': '1002910',
#   'distributed_pfizer': '2168405',
#   'distributed_unk_manuf': '0',
#   'location': 'NM',
#   'mmwr_week': '52',
#   'recip_administered': '3571517',
#   'series_complete_12plus': '1359001',
#   'series_complete_12pluspop': '76',
#   'series_complete_18plus': '1255234',
#   'series_complete_18pluspop': '77.4',
#   'series_complete_5plus': '1391328',
#   'series_complete_5pluspop_pct': '70.4',
#   'series_complete_65plus': '343754',
#   'series_complete_65pluspop': '91',
#   'series_complete_janssen': '104150',
#   'series_complete_janssen_12plus': '104135',
#   'series_complete_janssen_18plus': '103997',
#   'series_complete_janssen_5plus': '104141',
#   'series_complete_janssen_65plus': '20852',
#   'series_complete_moderna': '536344',
#   'series_complete_moderna_12plus': '536308',
#   'series_complete_moderna_18plus': '535924',
#   'series_complete_moderna_5plus': '536328',
#   'series_complete_moderna_65plus': '160893',
#   'series_complete_pfizer': '748903',
#   'series_complete_pfizer_12plus': '716578',
#   'series_complete_pfizer_18plus': '613359',
#   'series_complete_pfizer_5plus': '748879',
#   'series_complete_pfizer_65plus': '161013',
#   'series_complete_pop_pct': '66.4',
#   'series_complete_unk_manuf': '1980',
#   'series_complete_unk_manuf_1': '1980',
#   'series_complete_unk_manuf_2': '1954',
#   'series_complete_unk_manuf_3': '996',
#   'series_complete_unk_manuf_5plus': '1980',
#   'series_complete_yes': '1391377'},
#  {'additional_doses': '349350',
#   'additional_doses_18plus': '345771',
#   'additional_doses_18plus_vax_pct': '47',
#   'additional_doses_50plus': '233517',
#   'additional_doses_50plus_vax_pct': '60.5',
#   'additional_doses_65plus': '130277',
#   'additional_doses_65plus_vax_pct': '71.1',
#   'additional_doses_janssen': '4018',
#   'additional_doses_moderna': '154895',
#   'additional_doses_pfizer': '190415',
#   'additional_doses_unk_manuf': '22',
#   'additional_doses_vax_pct': '43',
#   'admin_per_100k': '185474',
#   'admin_per_100k_12plus': '206499',
#   'admin_per_100k_18plus': '210953',
#   'admin_per_100k_5plus': '195529',
#   'admin_per_100k_65plus': '272447',
#   'administered': '1964836',
#   'administered_12plus': '1915259',
#   'administered_18plus': '1803369',
#   'administered_5plus': '1964755',
#   'administered_65plus': '509602',
#   'administered_dose1_pop_pct': '89.5',
#   'administered_dose1_recip': '947819',
#   'administered_dose1_recip_12plus': '914468',
#   'administered_dose1_recip_12pluspop_pct': '95',
#   'administered_dose1_recip_18plus': '854585',
#   'administered_dose1_recip_18pluspop_pct': '95',
#   'administered_dose1_recip_5plus': '947745',
#   'administered_dose1_recip_5pluspop_pct': '94.3',
#   'administered_dose1_recip_65plus': '209321',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '62466',
#   'administered_moderna': '753721',
#   'administered_pfizer': '1147281',
#   'administered_unk_manuf': '1368',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '215430',
#   'distributed': '2282185',
#   'distributed_janssen': '87000',
#   'distributed_moderna': '853980',
#   'distributed_per_100k_12plus': '246060',
#   'distributed_per_100k_18plus': '266964',
#   'distributed_per_100k_5plus': '227119',
#   'distributed_per_100k_65plus': '1220120',
#   'distributed_pfizer': '1341205',
#   'distributed_unk_manuf': '0',
#   'location': 'RI',
#   'mmwr_week': '52',
#   'recip_administered': '2061964',
#   'series_complete_12plus': '788488',
#   'series_complete_12pluspop': '85',
#   'series_complete_18plus': '735450',
#   'series_complete_18pluspop': '86',
#   'series_complete_5plus': '812160',
#   'series_complete_5pluspop_pct': '80.8',
#   'series_complete_65plus': '183183',
#   'series_complete_65pluspop': '95',
#   'series_complete_janssen': '57676',
#   'series_complete_janssen_12plus': '57675',
#   'series_complete_janssen_18plus': '57649',
#   'series_complete_janssen_5plus': '57675',
#   'series_complete_janssen_65plus': '6605',
#   'series_complete_moderna': '280901',
#   'series_complete_moderna_12plus': '280892',
#   'series_complete_moderna_18plus': '280788',
#   'series_complete_moderna_5plus': '280897',
#   'series_complete_moderna_65plus': '82552',
#   'series_complete_pfizer': '473262',
#   'series_complete_pfizer_12plus': '449593',
#   'series_complete_pfizer_18plus': '396686',
#   'series_complete_pfizer_5plus': '473260',
#   'series_complete_pfizer_65plus': '93903',
#   'series_complete_pop_pct': '76.7',
#   'series_complete_unk_manuf': '329',
#   'series_complete_unk_manuf_1': '328',
#   'series_complete_unk_manuf_2': '327',
#   'series_complete_unk_manuf_3': '123',
#   'series_complete_unk_manuf_5plus': '328',
#   'series_complete_yes': '812168'},
#  {'additional_doses': '355067',
#   'additional_doses_18plus': '354438',
#   'additional_doses_18plus_vax_pct': '26.5',
#   'additional_doses_50plus': '293027',
#   'additional_doses_50plus_vax_pct': '37.3',
#   'additional_doses_65plus': '191870',
#   'additional_doses_65plus_vax_pct': '48.2',
#   'additional_doses_janssen': '5017',
#   'additional_doses_moderna': '171039',
#   'additional_doses_pfizer': '178708',
#   'additional_doses_unk_manuf': '303',
#   'additional_doses_vax_pct': '24.8',
#   'admin_per_100k': '113851',
#   'admin_per_100k_12plus': '133353',
#   'admin_per_100k_18plus': '139586',
#   'admin_per_100k_5plus': '121326',
#   'admin_per_100k_65plus': '210419',
#   'administered': '3388383',
#   'administered_12plus': '3362404',
#   'administered_18plus': '3179168',
#   'administered_5plus': '3388236',
#   'administered_65plus': '1024094',
#   'administered_dose1_pop_pct': '55.3',
#   'administered_dose1_recip': '1646026',
#   'administered_dose1_recip_12plus': '1628533',
#   'administered_dose1_recip_12pluspop_pct': '64.6',
#   'administered_dose1_recip_18plus': '1527439',
#   'administered_dose1_recip_18pluspop_pct': '67.1',
#   'administered_dose1_recip_5plus': '1645896',
#   'administered_dose1_recip_5pluspop_pct': '58.9',
#   'administered_dose1_recip_65plus': '433647',
#   'administered_dose1_recip_65pluspop_pct': '89.1',
#   'administered_janssen': '84886',
#   'administered_moderna': '1384202',
#   'administered_pfizer': '1917120',
#   'administered_unk_manuf': '2175',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '153987',
#   'distributed': '4582875',
#   'distributed_janssen': '215900',
#   'distributed_moderna': '1728300',
#   'distributed_per_100k_12plus': '181757',
#   'distributed_per_100k_18plus': '201218',
#   'distributed_per_100k_5plus': '164104',
#   'distributed_per_100k_65plus': '941636',
#   'distributed_pfizer': '2638675',
#   'distributed_unk_manuf': '0',
#   'location': 'MS',
#   'mmwr_week': '52',
#   'recip_administered': '3411658',
#   'series_complete_12plus': '1422098',
#   'series_complete_12pluspop': '56.4',
#   'series_complete_18plus': '1339137',
#   'series_complete_18pluspop': '58.8',
#   'series_complete_5plus': '1430628',
#   'series_complete_5pluspop_pct': '51.2',
#   'series_complete_65plus': '397722',
#   'series_complete_65pluspop': '81.7',
#   'series_complete_janssen': '80003',
#   'series_complete_janssen_12plus': '79988',
#   'series_complete_janssen_18plus': '79910',
#   'series_complete_janssen_5plus': '79992',
#   'series_complete_janssen_65plus': '17293',
#   'series_complete_moderna': '559724',
#   'series_complete_moderna_12plus': '559713',
#   'series_complete_moderna_18plus': '559399',
#   'series_complete_moderna_5plus': '559716',
#   'series_complete_moderna_65plus': '203017',
#   'series_complete_pfizer': '790188',
#   'series_complete_pfizer_12plus': '781655',
#   'series_complete_pfizer_18plus': '699107',
#   'series_complete_pfizer_5plus': '790178',
#   'series_complete_pfizer_65plus': '177055',
#   'series_complete_pop_pct': '48.1',
#   'series_complete_unk_manuf': '742',
#   'series_complete_unk_manuf_1': '742',
#   'series_complete_unk_manuf_2': '721',
#   'series_complete_unk_manuf_3': '357',
#   'series_complete_unk_manuf_5plus': '742',
#   'series_complete_yes': '1430657'},
#  {'additional_doses': '4686613',
#   'additional_doses_18plus': '4648178',
#   'additional_doses_18plus_vax_pct': '36.3',
#   'additional_doses_50plus': '3076212',
#   'additional_doses_50plus_vax_pct': '48.7',
#   'additional_doses_65plus': '1719843',
#   'additional_doses_65plus_vax_pct': '58.7',
#   'additional_doses_janssen': '80678',
#   'additional_doses_moderna': '2082738',
#   'additional_doses_pfizer': '2522950',
#   'additional_doses_unk_manuf': '247',
#   'additional_doses_vax_pct': '33.5',
#   'admin_per_100k': '177374',
#   'admin_per_100k_12plus': '201094',
#   'admin_per_100k_18plus': '205984',
#   'admin_per_100k_5plus': '188270',
#   'admin_per_100k_65plus': '241807',
#   'administered': '34505468',
#   'administered_12plus': '33729902',
#   'administered_18plus': '31773550',
#   'administered_5plus': '34503407',
#   'administered_65plus': '7970310',
#   'administered_dose1_pop_pct': '84.4',
#   'administered_dose1_recip': '16418510',
#   'administered_dose1_recip_12plus': '15935891',
#   'administered_dose1_recip_12pluspop_pct': '95',
#   'administered_dose1_recip_18plus': '14911019',
#   'administered_dose1_recip_18pluspop_pct': '95',
#   'administered_dose1_recip_5plus': '16416944',
#   'administered_dose1_recip_5pluspop_pct': '89.6',
#   'administered_dose1_recip_65plus': '3380035',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '1348370',
#   'administered_moderna': '12653266',
#   'administered_pfizer': '20488081',
#   'administered_unk_manuf': '15751',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '200600',
#   'distributed': '39023815',
#   'distributed_janssen': '1789500',
#   'distributed_moderna': '13379080',
#   'distributed_per_100k_12plus': '232655',
#   'distributed_per_100k_18plus': '252986',
#   'distributed_per_100k_5plus': '212936',
#   'distributed_per_100k_65plus': '1183920',
#   'distributed_pfizer': '23855235',
#   'distributed_unk_manuf': '0',
#   'location': 'NY',
#   'mmwr_week': '52',
#   'recip_administered': '34506220',
#   'series_complete_12plus': '13698391',
#   'series_complete_12pluspop': '81.7',
#   'series_complete_18plus': '12803487',
#   'series_complete_18pluspop': '83',
#   'series_complete_5plus': '13992363',
#   'series_complete_5pluspop_pct': '76.4',
#   'series_complete_65plus': '2927512',
#   'series_complete_65pluspop': '88.8',
#   'series_complete_janssen': '1205985',
#   'series_complete_janssen_12plus': '1205801',
#   'series_complete_janssen_18plus': '1205021',
#   'series_complete_janssen_5plus': '1205880',
#   'series_complete_janssen_65plus': '184043',
#   'series_complete_moderna': '4805884',
#   'series_complete_moderna_12plus': '4805309',
#   'series_complete_moderna_18plus': '4803317',
#   'series_complete_moderna_5plus': '4805768',
#   'series_complete_moderna_65plus': '1382685',
#   'series_complete_pfizer': '7976715',
#   'series_complete_pfizer_12plus': '7683184',
#   'series_complete_pfizer_18plus': '6791339',
#   'series_complete_pfizer_5plus': '7976560',
#   'series_complete_pfizer_65plus': '1359173',
#   'series_complete_pop_pct': '71.9',
#   'series_complete_unk_manuf': '4170',
#   'series_complete_unk_manuf_1': '4097',
#   'series_complete_unk_manuf_2': '3810',
#   'series_complete_unk_manuf_3': '1611',
#   'series_complete_unk_manuf_5plus': '4155',
#   'series_complete_yes': '13992754'},
#  {'additional_doses': '174074',
#   'additional_doses_18plus': '173176',
#   'additional_doses_18plus_vax_pct': '37.3',
#   'additional_doses_50plus': '129283',
#   'additional_doses_50plus_vax_pct': '49.5',
#   'additional_doses_65plus': '81784',
#   'additional_doses_65plus_vax_pct': '58.8',
#   'additional_doses_janssen': '2082',
#   'additional_doses_moderna': '80909',
#   'additional_doses_pfizer': '91075',
#   'additional_doses_unk_manuf': '8',
#   'additional_doses_vax_pct': '34.4',
#   'admin_per_100k': '143042',
#   'admin_per_100k_12plus': '167325',
#   'admin_per_100k_18plus': '174217',
#   'admin_per_100k_5plus': '153661',
#   'admin_per_100k_65plus': '247997',
#   'administered': '1265430',
#   'administered_12plus': '1235025',
#   'administered_18plus': '1162998',
#   'administered_5plus': '1265389',
#   'administered_65plus': '376635',
#   'administered_dose1_pop_pct': '71.1',
#   'administered_dose1_recip': '628825',
#   'administered_dose1_recip_12plus': '610399',
#   'administered_dose1_recip_12pluspop_pct': '82.7',
#   'administered_dose1_recip_18plus': '570357',
#   'administered_dose1_recip_18pluspop_pct': '85.4',
#   'administered_dose1_recip_5plus': '628786',
#   'administered_dose1_recip_5pluspop_pct': '76.4',
#   'administered_dose1_recip_65plus': '170334',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '38687',
#   'administered_moderna': '501336',
#   'administered_pfizer': '725275',
#   'administered_unk_manuf': '132',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '178745',
#   'distributed': '1581285',
#   'distributed_janssen': '86400',
#   'distributed_moderna': '623240',
#   'distributed_per_100k_12plus': '214237',
#   'distributed_per_100k_18plus': '236876',
#   'distributed_per_100k_5plus': '192022',
#   'distributed_per_100k_65plus': '1041200',
#   'distributed_pfizer': '871645',
#   'distributed_unk_manuf': '0',
#   'location': 'SD',
#   'mmwr_week': '52',
#   'recip_administered': '1275260',
#   'series_complete_12plus': '494429',
#   'series_complete_12pluspop': '67',
#   'series_complete_18plus': '463770',
#   'series_complete_18pluspop': '69.5',
#   'series_complete_5plus': '506049',
#   'series_complete_5pluspop_pct': '61.5',
#   'series_complete_65plus': '139102',
#   'series_complete_65pluspop': '91.6',
#   'series_complete_janssen': '36888',
#   'series_complete_janssen_12plus': '36883',
#   'series_complete_janssen_18plus': '36858',
#   'series_complete_janssen_5plus': '36884',
#   'series_complete_janssen_65plus': '4865',
#   'series_complete_moderna': '189475',
#   'series_complete_moderna_12plus': '189473',
#   'series_complete_moderna_18plus': '189409',
#   'series_complete_moderna_5plus': '189473',
#   'series_complete_moderna_65plus': '69233',
#   'series_complete_pfizer': '279663',
#   'series_complete_pfizer_12plus': '268041',
#   'series_complete_pfizer_18plus': '237471',
#   'series_complete_pfizer_5plus': '279660',
#   'series_complete_pfizer_65plus': '64984',
#   'series_complete_pop_pct': '57.2',
#   'series_complete_unk_manuf': '32',
#   'series_complete_unk_manuf_1': '32',
#   'series_complete_unk_manuf_2': '32',
#   'series_complete_unk_manuf_3': '20',
#   'series_complete_unk_manuf_5plus': '32',
#   'series_complete_yes': '506058'},
#  {'additional_doses': '1263612',
#   'additional_doses_18plus': '1254675',
#   'additional_doses_18plus_vax_pct': '33',
#   'additional_doses_50plus': '901388',
#   'additional_doses_50plus_vax_pct': '44',
#   'additional_doses_65plus': '566176',
#   'additional_doses_65plus_vax_pct': '51.7',
#   'additional_doses_janssen': '16553',
#   'additional_doses_moderna': '559389',
#   'additional_doses_pfizer': '687142',
#   'additional_doses_unk_manuf': '528',
#   'additional_doses_vax_pct': '30.4',
#   'admin_per_100k': '144621',
#   'admin_per_100k_12plus': '166165',
#   'admin_per_100k_18plus': '171222',
#   'admin_per_100k_5plus': '153684',
#   'admin_per_100k_65plus': '236218',
#   'administered': '10526589',
#   'administered_12plus': '10312283',
#   'administered_18plus': '9654302',
#   'administered_5plus': '10525714',
#   'administered_65plus': '3091227',
#   'administered_dose1_pop_pct': '67.4',
#   'administered_dose1_recip': '4908547',
#   'administered_dose1_recip_12plus': '4768158',
#   'administered_dose1_recip_12pluspop_pct': '76.8',
#   'administered_dose1_recip_18plus': '4418087',
#   'administered_dose1_recip_18pluspop_pct': '78.4',
#   'administered_dose1_recip_5plus': '4907817',
#   'administered_dose1_recip_5pluspop_pct': '71.7',
#   'administered_dose1_recip_65plus': '1252876',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '343834',
#   'administered_moderna': '4196653',
#   'administered_pfizer': '5965171',
#   'administered_unk_manuf': '20931',
#   'date': '2022-01-01T00:00:00.000',
#   'dist_per_100k': '172905',
#   'distributed': '12585270',
#   'distributed_janssen': '587500',
#   'distributed_moderna': '4637500',
#   'distributed_per_100k_12plus': '202790',
#   'distributed_per_100k_18plus': '223203',
#   'distributed_per_100k_5plus': '183755',
#   'distributed_per_100k_65plus': '961711',
#   'distributed_pfizer': '7360270',
#   'distributed_unk_manuf': '0',
#   'location': 'AZ',
#   'mmwr_week': '52',
#   'recip_administered': '10313874',
#   'series_complete_12plus': '4086943',
#   'series_complete_12pluspop': '65.9',
#   'series_complete_18plus': '3803033',
#   'series_complete_18pluspop': '67.4',
#   'series_complete_5plus': '4155418',
#   'series_complete_5pluspop_pct': '60.7',
#   'series_complete_65plus': '1094334',
#   'series_complete_65pluspop': '83.6',
#   'series_complete_janssen': '315969',
#   'series_complete_janssen_12plus': '315724',
#   'series_complete_janssen_18plus': '315521',
#   'series_complete_janssen_5plus': '315734',
#   'series_complete_janssen_65plus': '49306',
#   'series_complete_moderna': '1566977',
#   'series_complete_moderna_12plus': '1566937',
#   'series_complete_moderna_18plus': '1566299',
#   'series_complete_moderna_5plus': '1566959',
#   'series_complete_moderna_65plus': '533354',
#   'series_complete_pfizer': '2266940',
#   'series_complete_pfizer_12plus': '2198473',
#   'series_complete_pfizer_18plus': '1915482',
#   'series_complete_pfizer_5plus': '2266902',
#   'series_complete_pfizer_65plus': '508524',
#   'series_complete_pop_pct': '57.1',
#   'series_complete_unk_manuf': '5823',
#   'series_complete_unk_manuf_1': '5809',
#   'series_complete_unk_manuf_2': '5731',
#   'series_complete_unk_manuf_3': '3150',
#   'series_complete_unk_manuf_5plus': '5823',
#   'series_complete_yes': '4155709'},
#  {'additional_doses': '1619598',
#   'additional_doses_18plus': '1601128',
#   'additional_doses_18plus_vax_pct': '41.8',
#   'additional_doses_50plus': '1063646',
#   'additional_doses_50plus_vax_pct': '55.1',
#   'additional_doses_65plus': '586643',
#   'additional_doses_65plus_vax_pct': '66.1',
#   'additional_doses_janssen': '28337',
#   'additional_doses_moderna': '715886',
#   'additional_doses_pfizer': '875079',
#   'additional_doses_unk_manuf': '296',
#   'additional_doses_vax_pct': '38',
#   'admin_per_100k': '173154',
# ...
#   'series_complete_unk_manuf_2': '952',
#   'series_complete_unk_manuf_3': '581',
#   'series_complete_unk_manuf_5plus': '1037',
#   'series_complete_yes': '5752816'},
#  {'additional_doses': '80262336',
#   'additional_doses_18plus': '78868804',
#   'additional_doses_18plus_vax_pct': '41.5',
#   'additional_doses_50plus': '52315671',
#   'additional_doses_50plus_vax_pct': '53.1',
#   'additional_doses_65plus': '29894490',
#   'additional_doses_65plus_vax_pct': '62',
#   'additional_doses_janssen': '1195602',
#   'additional_doses_moderna': '35543444',
#   'additional_doses_pfizer': '43505477',
#   'additional_doses_unk_manuf': '17813',
#   'additional_doses_vax_pct': '38.4',
#   'admin_per_100k': '159003',
#   'admin_per_100k_12plus': '181455',
#   'admin_per_100k_18plus': '186905',
#   'admin_per_100k_5plus': '169039',
#   'admin_per_100k_65plus': '245114',
#   'administered': '527903848',
#   'administered_12plus': '514460137',
#   'administered_18plus': '482701005',
#   'administered_5plus': '527848795',
#   'administered_65plus': '134302800',
#   'administered_dose1_pop_pct': '75',
#   'administered_dose1_recip': '248993714',
#   'administered_dose1_recip_12plus': '240961113',
#   'administered_dose1_recip_12pluspop_pct': '85',
#   'administered_dose1_recip_18plus': '224513005',
#   'administered_dose1_recip_18pluspop_pct': '86.9',
#   'administered_dose1_recip_5plus': '248946760',
#   'administered_dose1_recip_5pluspop_pct': '79.7',
#   'administered_dose1_recip_65plus': '56294703',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '17964436',
#   'administered_moderna': '200845516',
#   'administered_pfizer': '308632239',
#   'administered_unk_manuf': '461657',
#   'date': '2022-01-16T00:00:00.000',
#   'dist_per_100k': '196248',
#   'distributed': '651561015',
#   'distributed_janssen': '29887900',
#   'distributed_moderna': '239546020',
#   'distributed_per_100k_12plus': '229811',
#   'distributed_per_100k_18plus': '252289',
#   'distributed_per_100k_5plus': '208656',
#   'distributed_per_100k_65plus': '1189150',
#   'distributed_pfizer': '382127095',
#   'distributed_unk_manuf': '0',
#   'location': 'US',
#   'mmwr_week': '2',
#   'recip_administered': '527903848',
#   'series_complete_12plus': '203780242',
#   'series_complete_12pluspop': '71.9',
#   'series_complete_18plus': '189980425',
#   'series_complete_18pluspop': '73.6',
#   'series_complete_5plus': '209122856',
#   'series_complete_5pluspop_pct': '67',
#   'series_complete_65plus': '48222936',
#   'series_complete_65pluspop': '88',
#   'series_complete_janssen': '16517672',
#   'series_complete_janssen_12plus': '16512991',
#   'series_complete_janssen_18plus': '16487840',
#   'series_complete_janssen_5plus': '16514710',
#   'series_complete_janssen_65plus': '2331524',
#   'series_complete_moderna': '74044973',
#   'series_complete_moderna_12plus': '74039467',
#   'series_complete_moderna_18plus': '73961620',
#   'series_complete_moderna_5plus': '74041828',
#   'series_complete_moderna_65plus': '23000472',
#   'series_complete_pfizer': '118438490',
#   'series_complete_pfizer_12plus': '113096846',
#   'series_complete_pfizer_18plus': '99404529',
#   'series_complete_pfizer_5plus': '118434449',
#   'series_complete_pfizer_65plus': '22831637',
#   'series_complete_pop_pct': '63',
#   'series_complete_unk_manuf': '131909',
#   'series_complete_unk_manuf_1': '130938',
#   'series_complete_unk_manuf_2': '126436',
#   'series_complete_unk_manuf_3': '59303',
#   'series_complete_unk_manuf_5plus': '131869',
#   'series_complete_yes': '209133044'},
#  {'additional_doses': '1807409',
#   'additional_doses_18plus': '1781876',
#   'additional_doses_18plus_vax_pct': '53.6',
#   'additional_doses_50plus': '1228261',
#   'additional_doses_50plus_vax_pct': '65.7',
#   'additional_doses_65plus': '724972',
#   'additional_doses_65plus_vax_pct': '76',
#   'additional_doses_janssen': '24599',
#   'additional_doses_moderna': '774708',
#   'additional_doses_pfizer': '1008030',
#   'additional_doses_unk_manuf': '72',
#   'additional_doses_vax_pct': '49.4',
#   'admin_per_100k': '162054',
#   'admin_per_100k_12plus': '183808',
#   'admin_per_100k_18plus': '190531',
#   'admin_per_100k_5plus': '171799',
#   'admin_per_100k_65plus': '271203',
#   'administered': '9435461',
#   'administered_12plus': '9190040',
#   'administered_18plus': '8680260',
#   'administered_5plus': '9435093',
#   'administered_65plus': '2758791',
#   'administered_dose1_pop_pct': '69.4',
#   'administered_dose1_recip': '4040022',
#   'administered_dose1_recip_12plus': '3901220',
#   'administered_dose1_recip_12pluspop_pct': '78',
#   'administered_dose1_recip_18plus': '3648465',
#   'administered_dose1_recip_18pluspop_pct': '80.1',
#   'administered_dose1_recip_5plus': '4039690',
#   'administered_dose1_recip_5pluspop_pct': '73.6',
#   'administered_dose1_recip_65plus': '1025317',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '327279',
#   'administered_moderna': '3648371',
#   'administered_pfizer': '5457839',
#   'administered_unk_manuf': '1972',
#   'date': '2022-01-16T00:00:00.000',
#   'dist_per_100k': '180754',
#   'distributed': '10524275',
#   'distributed_janssen': '449600',
#   'distributed_moderna': '3911140',
#   'distributed_per_100k_12plus': '210494',
#   'distributed_per_100k_18plus': '231006',
#   'distributed_per_100k_5plus': '191631',
#   'distributed_per_100k_65plus': '1034590',
#   'distributed_pfizer': '6163535',
#   'distributed_unk_manuf': '0',
#   'location': 'WI',
#   'mmwr_week': '2',
#   'recip_administered': '9411478',
#   'series_complete_12plus': '3550095',
#   'series_complete_12pluspop': '71',
#   'series_complete_18plus': '3326821',
#   'series_complete_18pluspop': '73',
#   'series_complete_5plus': '3655386',
#   'series_complete_5pluspop_pct': '66.6',
#   'series_complete_65plus': '954282',
#   'series_complete_65pluspop': '93.8',
#   'series_complete_janssen': '294285',
#   'series_complete_janssen_12plus': '294257',
#   'series_complete_janssen_18plus': '294066',
#   'series_complete_janssen_5plus': '294269',
#   'series_complete_janssen_65plus': '30302',
#   'series_complete_moderna': '1302865',
#   'series_complete_moderna_12plus': '1302825',
#   'series_complete_moderna_18plus': '1302496',
#   'series_complete_moderna_5plus': '1302855',
#   'series_complete_moderna_65plus': '458407',
#   'series_complete_pfizer': '2057620',
#   'series_complete_pfizer_12plus': '1952351',
#   'series_complete_pfizer_18plus': '1729626',
#   'series_complete_pfizer_5plus': '2057599',
#   'series_complete_pfizer_65plus': '465299',
#   'series_complete_pop_pct': '62.8',
#   'series_complete_unk_manuf': '663',
#   'series_complete_unk_manuf_1': '662',
#   'series_complete_unk_manuf_2': '633',
#   'series_complete_unk_manuf_3': '274',
#   'series_complete_unk_manuf_5plus': '663',
#   'series_complete_yes': '3655433'},
#  {'additional_doses': '2011',
#   'additional_doses_18plus': '2008',
#   'additional_doses_18plus_vax_pct': '9.3',
#   'additional_doses_50plus': '776',
#   'additional_doses_50plus_vax_pct': '15',
#   'additional_doses_65plus': '207',
#   'additional_doses_65plus_vax_pct': '16.7',
#   'additional_doses_janssen': '8',
#   'additional_doses_moderna': '1990',
#   'additional_doses_pfizer': '13',
#   'additional_doses_unk_manuf': '0',
#   'additional_doses_vax_pct': '8.7',
#   'admin_per_100k': '63681',
#   'admin_per_100k_12plus': '85727',
#   'admin_per_100k_18plus': '96329',
#   'admin_per_100k_5plus': '71517',
#   'admin_per_100k_65plus': '73232',
#   'administered': '49506',
#   'administered_12plus': '49181',
#   'administered_18plus': '45784',
#   'administered_5plus': '49488',
#   'administered_65plus': '2733',
#   'administered_dose1_pop_pct': '34.2',
#   'administered_dose1_recip': '26550',
#   'administered_dose1_recip_12plus': '26288',
#   'administered_dose1_recip_12pluspop_pct': '45.8',
#   'administered_dose1_recip_18plus': '24489',
#   'administered_dose1_recip_18pluspop_pct': '51.5',
#   'administered_dose1_recip_5plus': '26538',
#   'administered_dose1_recip_5pluspop_pct': '38.4',
#   'administered_dose1_recip_65plus': '1397',
#   'administered_dose1_recip_65pluspop_pct': '37.4',
#   'administered_janssen': '2607',
#   'administered_moderna': '43076',
#   'administered_pfizer': '3821',
#   'administered_unk_manuf': '2',
#   'date': '2022-01-16T00:00:00.000',
#   'dist_per_100k': '88731',
#   'distributed': '68980',
#   'distributed_janssen': '12100',
#   'distributed_moderna': '47700',
#   'distributed_per_100k_12plus': '120239',
#   'distributed_per_100k_18plus': '145132',
#   'distributed_per_100k_5plus': '99685',
#   'distributed_per_100k_65plus': '1848340',
#   'distributed_pfizer': '9180',
#   'distributed_unk_manuf': '0',
#   'location': 'MH',
#   'mmwr_week': '2',
#   'recip_administered': '49577',
#   'series_complete_12plus': '23142',
#   'series_complete_12pluspop': '40.3',
#   'series_complete_18plus': '21696',
#   'series_complete_18pluspop': '45.6',
#   'series_complete_5plus': '23194',
#   'series_complete_5pluspop_pct': '33.5',
#   'series_complete_65plus': '1236',
#   'series_complete_65pluspop': '33.1',
#   'series_complete_janssen': '2590',
#   'series_complete_janssen_12plus': '2587',
#   'series_complete_janssen_18plus': '2581',
#   'series_complete_janssen_5plus': '2589',
#   'series_complete_janssen_65plus': '114',
#   'series_complete_moderna': '19048',
#   'series_complete_moderna_12plus': '19040',
#   'series_complete_moderna_18plus': '19012',
#   'series_complete_moderna_5plus': '19043',
#   'series_complete_moderna_65plus': '1121',
#   'series_complete_pfizer': '1562',
#   'series_complete_pfizer_12plus': '1514',
#   'series_complete_pfizer_18plus': '102',
#   'series_complete_pfizer_5plus': '1561',
#   'series_complete_pfizer_65plus': '1',
#   'series_complete_pop_pct': '29.8',
#   'series_complete_unk_manuf': '1',
#   'series_complete_unk_manuf_1': '1',
#   'series_complete_unk_manuf_2': '1',
#   'series_complete_unk_manuf_3': '0',
#   'series_complete_unk_manuf_5plus': '1',
#   'series_complete_yes': '23201'},
#  {'additional_doses': '469634',
#   'additional_doses_18plus': '465867',
#   'additional_doses_18plus_vax_pct': '34.3',
#   'additional_doses_50plus': '365380',
#   'additional_doses_50plus_vax_pct': '46.1',
#   'additional_doses_65plus': '225313',
#   'additional_doses_65plus_vax_pct': '56.3',
#   'additional_doses_janssen': '6828',
#   'additional_doses_moderna': '223134',
#   'additional_doses_pfizer': '239309',
#   'additional_doses_unk_manuf': '363',
#   'additional_doses_vax_pct': '32.1',
#   'admin_per_100k': '120428',
#   'admin_per_100k_12plus': '140317',
#   'admin_per_100k_18plus': '146879',
#   'admin_per_100k_5plus': '128335',
#   'admin_per_100k_65plus': '218912',
#   'administered': '3584129',
#   'administered_12plus': '3537980',
#   'administered_18plus': '3345272',
#   'administered_5plus': '3583968',
#   'administered_65plus': '1065428',
#   'administered_dose1_pop_pct': '56.9',
#   'administered_dose1_recip': '1693462',
#   'administered_dose1_recip_12plus': '1663634',
#   'administered_dose1_recip_12pluspop_pct': '66',
#   'administered_dose1_recip_18plus': '1558632',
#   'administered_dose1_recip_18pluspop_pct': '68.4',
#   'administered_dose1_recip_5plus': '1693317',
#   'administered_dose1_recip_5pluspop_pct': '60.6',
#   'administered_dose1_recip_65plus': '438072',
#   'administered_dose1_recip_65pluspop_pct': '90',
#   'administered_janssen': '88338',
#   'administered_moderna': '1457965',
#   'administered_pfizer': '2035479',
#   'administered_unk_manuf': '2347',
#   'date': '2022-01-16T00:00:00.000',
#   'dist_per_100k': '166763',
#   'distributed': '4963115',
#   'distributed_janssen': '218800',
#   'distributed_moderna': '1972560',
#   'distributed_per_100k_12plus': '196838',
#   'distributed_per_100k_18plus': '217913',
#   'distributed_per_100k_5plus': '177719',
#   'distributed_per_100k_65plus': '1019760',
#   'distributed_pfizer': '2771755',
#   'distributed_unk_manuf': '0',
#   'location': 'MS',
#   'mmwr_week': '2',
#   'recip_administered': '3604220',
#   'series_complete_12plus': '1445481',
#   'series_complete_12pluspop': '57.3',
#   'series_complete_18plus': '1360108',
#   'series_complete_18pluspop': '59.7',
#   'series_complete_5plus': '1461416',
#   'series_complete_5pluspop_pct': '52.3',
#   'series_complete_65plus': '400197',
#   'series_complete_65pluspop': '82.2',
#   'series_complete_janssen': '81583',
#   'series_complete_janssen_12plus': '81568',
#   'series_complete_janssen_18plus': '81487',
#   'series_complete_janssen_5plus': '81572',
#   'series_complete_janssen_65plus': '17463',
#   'series_complete_moderna': '567479',
#   'series_complete_moderna_12plus': '567464',
#   'series_complete_moderna_18plus': '567139',
#   'series_complete_moderna_5plus': '567471',
#   'series_complete_moderna_65plus': '204229',
#   'series_complete_pfizer': '811565',
#   'series_complete_pfizer_12plus': '795631',
#   'series_complete_pfizer_18plus': '710688',
#   'series_complete_pfizer_5plus': '811555',
#   'series_complete_pfizer_65plus': '178118',
#   'series_complete_pop_pct': '49.1',
#   'series_complete_unk_manuf': '818',
#   'series_complete_unk_manuf_1': '818',
#   'series_complete_unk_manuf_2': '794',
#   'series_complete_unk_manuf_3': '387',
#   'series_complete_unk_manuf_5plus': '818',
#   'series_complete_yes': '1461445'},
#  {'additional_doses': '400063',
#   'additional_doses_18plus': '392079',
#   'additional_doses_18plus_vax_pct': '52.8',
#   'additional_doses_50plus': '253478',
#   'additional_doses_50plus_vax_pct': '65.3',
#   'additional_doses_65plus': '136803',
#   'additional_doses_65plus_vax_pct': '74.4',
#   'additional_doses_janssen': '4417',
#   'additional_doses_moderna': '175031',
#   'additional_doses_pfizer': '220592',
#   'additional_doses_unk_manuf': '23',
#   'additional_doses_vax_pct': '48.5',
#   'admin_per_100k': '192209',
#   'admin_per_100k_12plus': '213446',
#   'admin_per_100k_18plus': '217785',
#   'admin_per_100k_5plus': '202628',
#   'admin_per_100k_65plus': '276754',
#   'administered': '2036182',
#   'administered_12plus': '1979690',
#   'administered_18plus': '1861766',
#   'administered_5plus': '2036090',
#   'administered_65plus': '517658',
#   'administered_dose1_pop_pct': '91.9',
#   'administered_dose1_recip': '973798',
#   'administered_dose1_recip_12plus': '936070',
#   'administered_dose1_recip_12pluspop_pct': '95',
#   'administered_dose1_recip_18plus': '874489',
#   'administered_dose1_recip_18pluspop_pct': '95',
#   'administered_dose1_recip_5plus': '973714',
#   'administered_dose1_recip_5pluspop_pct': '95',
#   'administered_dose1_recip_65plus': '211037',
#   'administered_dose1_recip_65pluspop_pct': '95',
#   'administered_janssen': '63359',
#   'administered_moderna': '780582',
#   'administered_pfizer': '1190811',
#   'administered_unk_manuf': '1430',
#   'date': '2022-01-16T00:00:00.000',
#   'dist_per_100k': '226803',
#   'distributed': '2402665',
#   'distributed_janssen': '87000',
#   'distributed_moderna': '902540',
#   'distributed_per_100k_12plus': '259050',
#   'distributed_per_100k_18plus': '281057',
#   'distributed_per_100k_5plus': '239109',
#   'distributed_per_100k_65plus': '1284530',
#   'distributed_pfizer': '1413125',
#   'distributed_unk_manuf': '0',
#   'location': 'RI',
#   'mmwr_week': '2',
#   'recip_administered': '2151700',
#   'series_complete_12plus': '796867',
#   'series_complete_12pluspop': '85.9',
#   'series_complete_18plus': '742731',
#   'series_complete_18pluspop': '86.9',
#   'series_complete_5plus': '824867',
#   'series_complete_5pluspop_pct': '82.1',
#   'series_complete_65plus': '183816',
#   'series_complete_65pluspop': '95',
#   'series_complete_janssen': '58090',
#   'series_complete_janssen_12plus': '58089',
#   'series_complete_janssen_18plus': '58063',
#   'series_complete_janssen_5plus': '58089',
#   'series_complete_janssen_65plus': '6635',
#   'series_complete_moderna': '283194',
#   'series_complete_moderna_12plus': '283185',
#   'series_complete_moderna_18plus': '283078',
#   'series_complete_moderna_5plus': '283190',
#   'series_complete_moderna_65plus': '82764',
#   'series_complete_pfizer': '483243',
#   'series_complete_pfizer_12plus': '455246',
#   'series_complete_pfizer_18plus': '401244',
#   'series_complete_pfizer_5plus': '483241',
#   'series_complete_pfizer_65plus': '94291',
#   'series_complete_pop_pct': '77.9',
#   'series_complete_unk_manuf': '348',
#   'series_complete_unk_manuf_1': '347',
#   'series_complete_unk_manuf_2': '346',
#   'series_complete_unk_manuf_3': '126',
#   'series_complete_unk_manuf_5plus': '347',
#   'series_complete_yes': '824875'}]

# %%
#create data frame from json
original_data_frame=pd.DataFrame(response)
original_data_frame.tail()
# Out:
#                         date mmwr_week location distributed  \
# 995  2022-01-16T00:00:00.000         2       US   651561015
# 996  2022-01-16T00:00:00.000         2       WI    10524275
# 997  2022-01-16T00:00:00.000         2       MH       68980
# 998  2022-01-16T00:00:00.000         2       MS     4963115
# 999  2022-01-16T00:00:00.000         2       RI     2402665
#
#     distributed_janssen distributed_moderna distributed_pfizer  \
# 995            29887900           239546020          382127095
# 996              449600             3911140            6163535
# 997               12100               47700               9180
# 998              218800             1972560            2771755
# 999               87000              902540            1413125
#
#     distributed_unk_manuf dist_per_100k distributed_per_100k_5plus  ...  \
# 995                     0        196248                     208656  ...
# 996                     0        180754                     191631  ...
# 997                     0         88731                      99685  ...
# 998                     0        166763                     177719  ...
# 999                     0        226803                     239109  ...
#
#     additional_doses_18plus additional_doses_18plus_vax_pct  \
# 995                78868804                            41.5
# 996                 1781876                            53.6
# 997                    2008                             9.3
# 998                  465867                            34.3
# 999                  392079                            52.8
#
#     additional_doses_50plus additional_doses_50plus_vax_pct  \
# 995                52315671                            53.1
# 996                 1228261                            65.7
# 997                     776                              15
# 998                  365380                            46.1
# 999                  253478                            65.3
#
#     additional_doses_65plus additional_doses_65plus_vax_pct  \
# 995                29894490                              62
# 996                  724972                              76
# 997                     207                            16.7
# 998                  225313                            56.3
# 999                  136803                            74.4
#
#     additional_doses_moderna additional_doses_pfizer additional_doses_janssen  \
# 995                 35543444                43505477                  1195602
# 996                   774708                 1008030                    24599
# 997                     1990                      13                        8
# 998                   223134                  239309                     6828
# 999                   175031                  220592                     4417
#
#     additional_doses_unk_manuf
# 995                      17813
# 996                         72
# 997                          0
# 998                        363
# 999                         23
#
# [5 rows x 80 columns]

# %%
#organize the data frame with desired columns
vaccine_organized_data=original_data_frame[['date','location','administered','admin_per_100k','series_complete_yes']]
vaccine_organized_data
# Out:
#                         date location administered admin_per_100k  \
# 0    2022-01-01T00:00:00.000       LA      5671632         122002
# 1    2022-01-01T00:00:00.000       KS      4086457         140268
# 2    2022-01-01T00:00:00.000       OR      6852601         162471
# 3    2022-01-01T00:00:00.000       MO      8110832         132154
# 4    2022-01-01T00:00:00.000       AR      3800418         125933
# ..                       ...      ...          ...            ...
# 995  2022-01-16T00:00:00.000       US    527903848         159003
# 996  2022-01-16T00:00:00.000       WI      9435461         162054
# 997  2022-01-16T00:00:00.000       MH        49506          63681
# 998  2022-01-16T00:00:00.000       MS      3584129         120428
# 999  2022-01-16T00:00:00.000       RI      2036182         192209
#
#     series_complete_yes
# 0               2342010
# 1               1663083
# 2               2805578
# 3               3258083
# 4               1545587
# ..                  ...
# 995           209133044
# 996             3655433
# 997               23201
# 998             1461445
# 999              824875
#
# [1000 rows x 5 columns]

# %%
csvpath=os.path.join('..','Angad','income_data.csv')

# %%
with open(csvpath) as csvfile:
    csvreader=csv.reader(csvfile, delimiter=',')
    print (csvreader)
    csv_header=next(csvreader)
    print(f"CSV Header: {csv_header}")
    #for row in csvreader:
    #    print(row)
# Out:
# <_csv.reader object at 0x17685c510>
# CSV Header: ['\ufeff"Label (Grouping)"', 'Alabama!!Households!!Estimate', 'Alabama!!Households!!Margin of Error', 'Alabama!!Families!!Estimate', 'Alabama!!Families!!Margin of Error', 'Alabama!!Married-couple families!!Estimate', 'Alabama!!Married-couple families!!Margin of Error', 'Alabama!!Nonfamily households!!Estimate', 'Alabama!!Nonfamily households!!Margin of Error', 'Alaska!!Households!!Estimate', 'Alaska!!Households!!Margin of Error', 'Alaska!!Families!!Estimate', 'Alaska!!Families!!Margin of Error', 'Alaska!!Married-couple families!!Estimate', 'Alaska!!Married-couple families!!Margin of Error', 'Alaska!!Nonfamily households!!Estimate', 'Alaska!!Nonfamily households!!Margin of Error', 'Arizona!!Households!!Estimate', 'Arizona!!Households!!Margin of Error', 'Arizona!!Families!!Estimate', 'Arizona!!Families!!Margin of Error', 'Arizona!!Married-couple families!!Estimate', 'Arizona!!Married-couple families!!Margin of Error', 'Arizona!!Nonfamily households!!Estimate', 'Arizona!!Nonfamily households!!Margin of Error', 'Arkansas!!Households!!Estimate', 'Arkansas!!Households!!Margin of Error', 'Arkansas!!Families!!Estimate', 'Arkansas!!Families!!Margin of Error', 'Arkansas!!Married-couple families!!Estimate', 'Arkansas!!Married-couple families!!Margin of Error', 'Arkansas!!Nonfamily households!!Estimate', 'Arkansas!!Nonfamily households!!Margin of Error', 'California!!Households!!Estimate', 'California!!Households!!Margin of Error', 'California!!Families!!Estimate', 'California!!Families!!Margin of Error', 'California!!Married-couple families!!Estimate', 'California!!Married-couple families!!Margin of Error', 'California!!Nonfamily households!!Estimate', 'California!!Nonfamily households!!Margin of Error', 'Colorado!!Households!!Estimate', 'Colorado!!Households!!Margin of Error', 'Colorado!!Families!!Estimate', 'Colorado!!Families!!Margin of Error', 'Colorado!!Married-couple families!!Estimate', 'Colorado!!Married-couple families!!Margin of Error', 'Colorado!!Nonfamily households!!Estimate', 'Colorado!!Nonfamily households!!Margin of Error', 'Connecticut!!Households!!Estimate', 'Connecticut!!Households!!Margin of Error', 'Connecticut!!Families!!Estimate', 'Connecticut!!Families!!Margin of Error', 'Connecticut!!Married-couple families!!Estimate', 'Connecticut!!Married-couple families!!Margin of Error', 'Connecticut!!Nonfamily households!!Estimate', 'Connecticut!!Nonfamily households!!Margin of Error', 'Delaware!!Households!!Estimate', 'Delaware!!Households!!Margin of Error', 'Delaware!!Families!!Estimate', 'Delaware!!Families!!Margin of Error', 'Delaware!!Married-couple families!!Estimate', 'Delaware!!Married-couple families!!Margin of Error', 'Delaware!!Nonfamily households!!Estimate', 'Delaware!!Nonfamily households!!Margin of Error', 'District of Columbia!!Households!!Estimate', 'District of Columbia!!Households!!Margin of Error', 'District of Columbia!!Families!!Estimate', 'District of Columbia!!Families!!Margin of Error', 'District of Columbia!!Married-couple families!!Estimate', 'District of Columbia!!Married-couple families!!Margin of Error', 'District of Columbia!!Nonfamily households!!Estimate', 'District of Columbia!!Nonfamily households!!Margin of Error', 'Florida!!Households!!Estimate', 'Florida!!Households!!Margin of Error', 'Florida!!Families!!Estimate', 'Florida!!Families!!Margin of Error', 'Florida!!Married-couple families!!Estimate', 'Florida!!Married-couple families!!Margin of Error', 'Florida!!Nonfamily households!!Estimate', 'Florida!!Nonfamily households!!Margin of Error', 'Georgia!!Households!!Estimate', 'Georgia!!Households!!Margin of Error', 'Georgia!!Families!!Estimate', 'Georgia!!Families!!Margin of Error', 'Georgia!!Married-couple families!!Estimate', 'Georgia!!Married-couple families!!Margin of Error', 'Georgia!!Nonfamily households!!Estimate', 'Georgia!!Nonfamily households!!Margin of Error', 'Hawaii!!Households!!Estimate', 'Hawaii!!Households!!Margin of Error', 'Hawaii!!Families!!Estimate', 'Hawaii! ...

# %%
# Create an empty list to store the CSV data
data = []

# Open the CSV file and read its contents
with open(csvpath, newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Store the CSV data in the 'data' list
    for row in csvreader:
        data.append(row)

# Create a DataFrame from the 'data' list
income_df = pd.DataFrame(data, columns=data[0])

# Remove the header row from the DataFrame (if needed)
income_df = df[1:]

# Now, 'df' is your DataFrame containing the CSV data
print(income_df)
# Out:
#                            ﻿"Label (Grouping)" Alabama!!Households!!Estimate  \
# 2                            Less than $10,000                          7.6%
# 3                           $10,000 to $14,999                          5.2%
# 4                           $15,000 to $24,999                          9.3%
# 5                           $25,000 to $34,999                          8.6%
# 6                           $35,000 to $49,999                         12.0%
# 7                           $50,000 to $74,999                         16.7%
# 8                           $75,000 to $99,999                         12.6%
# 9                         $100,000 to $149,999                         14.9%
# 10                        $150,000 to $199,999                          6.4%
# 11                            $200,000 or more                          6.7%
# 12                     Median income (dollars)                        59,674
# 13                       Mean income (dollars)                        82,956
# 14                           PERCENT ALLOCATED
# 15      Household income in the past 12 months                         38.9%
# 16         Family income in the past 12 months                           (X)
# 17      Nonfamily income in the past 12 months                           (X)
#
#    Alabama!!Households!!Margin of Error Alabama!!Families!!Estimate  \
# 2                                  ±0.3                        4.4%
# 3                                  ±0.3                        3.0%
# 4                                  ±0.3                        6.0%
# 5                                  ±0.5                        6.9%
# 6                                  ±0.4                       10.7%
# 7                                  ±0.5                       17.3%
# 8                                  ±0.4                       14.4%
# 9                                  ±0.5                       19.4%
# 10                                 ±0.3                        8.7%
# 11                                 ±0.3                        9.2%
# 12                                 ±727                      77,668
# 13                               ±1,020                     100,785
# 14
# 15                                  (X)                         (X)
# 16                                  (X)                       40.8%
# 17                                  (X)                         (X)
#
#    Alabama!!Families!!Margin of Error  \
# 2                                ±0.4
# 3                                ±0.3
# 4                                ±0.4
# 5                                ±0.5
# 6                                ±0.5
# 7                                ±0.5
# 8                                ±0.5
# 9                                ±0.7
# 10                               ±0.4
# 11                               ±0.5
# 12                             ±1,070
# 13                             ±1,464
# 14
# 15                                (X)
# 16                                (X)
# 17                                (X)
#
#    Alabama!!Married-couple families!!Estimate  \
# 2                                        1.7%
# 3                                        1.1%
# 4                                        3.4%
# 5                                        4.9%
# 6                                        8.4%
# 7                                       17.2%
# 8                                       16.5%
# 9                                       23.6%
# 10                                      11.2%
# 11                                      12.1%
# 12                                     94,370
# 13                                    118,799
# 14
# 15                                        (X)
# 16                                        (X)
# 17                                        (X)
#
#    Alabama!!Married-couple families!!Margin of Error  \
# 2                                               ±0.2
# 3                                               ±0.2
# 4                                               ±0.3
# 5                                               ±0.4
# 6                                               ±0.5
# 7                                               ±0.6
# 8                                               ±0.6
# 9                                               ±0.9
# 10                                              ±0.6
# 11                                              ±0.6
# 12                                            ±1,174
# 13                                            ±1,673
# 14
# 15                                               (X)
# 16                                               (X)
# 17                                               (X)
#
#    Alabama!!Nonfamily households!!Estimate  \
# 2                                    14.3%
# 3                                     9.8%
# 4                                    15.9%
# 5                                    12.5%
# 6                                    14.5%
# 7                                    15.7%
# 8                                     8.1%
# 9                                     5.7%
# 10                                    1.9%
# 11                                    1.6%
# 12                                  32,330
# 13                                  47,145
# 14
# 15                                     (X)
# 16                                     (X)
# 17                                   34.2%
#
#    Alabama!!Nonfamily households!!Margin of Error  \
# 2                                            ±0.8
# 3                                            ±0.6
# 4                                            ±0.7
# 5                                            ±0.8
# 6                                            ±0.7
# 7                                            ±1.0
# 8                                            ±0.6
# 9                                            ±0.5
# 10                                           ±0.3
# 11                                           ±0.3
# 12                                           ±919
# 13                                         ±1,778
# 14
# 15                                            (X)
# 16                                            (X)
# 17                                            (X)
#
#    Alaska!!Households!!Estimate  ... Wyoming!!Nonfamily households!!Estimate  \
# 2                          4.4%  ...                                    9.6%
# 3                          2.5%  ...                                    6.9%
# 4                          5.4%  ...                                   13.3%
# 5                          5.3%  ...                                   12.7%
# 6                          9.1%  ...                                   15.9%
# 7                         15.8%  ...                                   17.5%
# 8                         13.2%  ...                                   10.4%
# 9                         21.8%  ...                                    8.2%
# 10                        11.1%  ...                                    2.2%
# 11                        11.4%  ...                                    3.3%
# 12                       88,121  ...                                  40,019
# 13                      109,524  ...                                  57,301
# 14                               ...
# 15                        35.9%  ...                                     (X)
# 16                          (X)  ...                                     (X)
# 17                          (X)  ...                                   28.8%
#
#    Wyoming!!Nonfamily households!!Margin of Error  \
# 2                                            ±1.7
# 3                                            ±1.4
# 4                                            ±1.9
# 5                                            ±1.8
# 6                                            ±2.0
# 7                                            ±2.0
# 8                                            ±1.7
# 9                                            ±1.9
# 10                                           ±0.9
# 11                                           ±1.2
# 12                                         ±2,776
# 13                                         ±3,886
# 14
# 15                                            (X)
# 16                                            (X)
# 17                                            (X)
#
#    Puerto Rico!!Households!!Estimate Puerto Rico!!Households!!Margin of Error  \
# 2                              22.4%                                     ±0.6
# 3                              10.8%                                     ±0.5
# 4                              18.2%                                     ±0.6
# 5                              12.5%                                     ±0.5
# 6                              12.9%                                     ±0.6
# 7                              10.8%                                     ±0.4
# 8                               5.6%                                     ±0.4
# 9                               3.9%                                     ±0.3
# 10                              1.6%                                     ±0.2
# 11                              1.5%                                     ±0.2
# 12                            24,112                                     ±515
# 13                            39,142                                     ±949
# 14
# 15                             35.5%                                      (X)
# 16                               (X)                                      (X)
# 17                               (X)                                      (X)
#
#    Puerto Rico!!Families!!Estimate Puerto Rico!!Families!!Margin of Error  \
# 2                            16.7%                                   ±0.8
# 3                             8.9%                                   ±0.6
# 4                            18.1%                                   ±0.8
# 5                            13.6%                                   ±0.7
# 6                            14.3%                                   ±0.8
# 7                            13.2%                                   ±0.7
# 8                             6.7%                                   ±0.5
# 9                             4.9%                                   ±0.4
# 10                            1.9%                                   ±0.3
# 11                            1.8%                                   ±0.3
# 12                          29,544                                   ±757
# 13                          45,243                                 ±1,375
# 14
# 15                             (X)                                    (X)
# 16                           38.1%                                    (X)
# 17                             (X)                                    (X)
#
#    Puerto Rico!!Married-couple families!!Estimate  \
# 2                                            7.7%
# 3                                            7.4%
# 4                                           16.0%
# 5                                           13.4%
# 6                                           16.3%
# 7                                           16.5%
# 8                                            9.2%
# 9                                            7.2%
# 10                                           3.1%
# 11                                           3.1%
# 12                                         39,637
# 13                                         59,169
# 14
# 15                                            (X)
# 16                                            (X)
# 17                                            (X)
#
#    Puerto Rico!!Married-couple families!!Margin of Error  \
# 2                                                ±0.7
# 3                                                ±0.7
# 4                                                ±0.9
# 5                                                ±0.9
# 6                                                ±1.3
# 7                                                ±0.9
# 8                                                ±0.8
# 9                                                ±0.7
# 10                                               ±0.5
# 11                                               ±0.5
# 12                                             ±1,117
# 13                                             ±2,220
# 14
# 15                                                (X)
# 16                                                (X)
# 17                                                (X)
#
#    Puerto Rico!!Nonfamily households!!Estimate  \
# 2                                        35.1%
# 3                                        14.9%
# 4                                        19.8%
# 5                                        10.6%
# 6                                         8.7%
# 7                                         5.2%
# 8                                         2.6%
# 9                                         1.7%
# 10                                        0.8%
# 11                                        0.6%
# 12                                      15,006
# 13                                      24,694
# 14
# 15                                         (X)
# 16                                         (X)
# 17                                       28.2%
#
#    Puerto Rico!!Nonfamily households!!Margin of Error
# 2                                                ±1.2
# 3                                                ±0.9
# 4                                                ±0.9
# 5                                                ±0.8
# 6                                                ±0.7
# 7                                                ±0.6
# 8                                                ±0.4
# 9                                                ±0.3
# 10                                               ±0.3
# 11                                               ±0.2
# 12                                               ±414
# 13                                               ±893
# 14
# 15                                                (X)
# 16                                                (X)
# 17                                                (X)
#
# [16 rows x 417 columns]

# %%
#organize the data frame with desired columns
income_organized_data=income_df[[
                                'Alabama!!Households!!Estimate',
                                'Alaska!!Households!!Estimate',
                                "Arizona!!Households!!Estimate",
                                "Arkansas!!Households!!Estimate",
                                "California!!Households!!Estimate",
                                "Colorado!!Households!!Estimate",
                                "Connecticut!!Households!!Estimate",
                                "Delaware!!Households!!Estimate",
                                "District of Columbia!!Households!!Estimate",
                                "Florida!!Households!!Estimate",
                                "Georgia!!Households!!Estimate",
                                "Hawaii!!Households!!Estimate",
                                "Idaho!!Households!!Estimate",
                                "Illinois!!Households!!Estimate",
                                "Indiana!!Households!!Estimate",
                                "Iowa!!Households!!Estimate",
                                "Kansas!!Households!!Estimate",
                                "Kentucky!!Households!!Estimate",
                                "Louisiana!!Households!!Estimate",
                                "Maine!!Households!!Estimate",
                                "Maryland!!Households!!Estimate",
                                "Massachusetts!!Households!!Estimate",
                                "Michigan!!Households!!Estimate",
                                "Minnesota!!Households!!Estimate",
                                "Mississippi!!Households!!Estimate",
                                "Missouri!!Households!!Estimate",
                                "Montana!!Households!!Estimate",
                                "Nebraska!!Households!!Estimate",
                                "Nevada!!Households!!Estimate",
                                "New Hampshire!!Households!!Estimate",
                                "New Jersey!!Households!!Estimate",
                                "New Mexico!!Households!!Estimate",
                                "New York!!Households!!Estimate",
                                "North Carolina!!Households!!Estimate",
                                "North Dakota!!Households!!Estimate",
                                "Ohio!!Households!!Estimate",
                                "Oklahoma!!Households!!Estimate",
                                "Oregon!!Households!!Estimate",
                                "Pennsylvania!!Households!!Estimate",
                                "Rhode Island!!Households!!Estimate",
                                "South Carolina!!Households!!Estimate",
                                "South Dakota!!Households!!Estimate",
                                "Tennessee!!Households!!Estimate",
                                "Texas!!Households!!Estimate",
                                "Utah!!Households!!Estimate",
                                "Vermont!!Households!!Estimate",
                                "Virginia!!Households!!Estimate",
                                "Washington!!Households!!Estimate",
                                "West Virginia!!Households!!Estimate",
                                "Wisconsin!!Households!!Estimate",
                                "Wyoming!!Households!!Estimate",
                                





                                ]]
income_organized_data
# Out:
#    Alabama!!Households!!Estimate Alaska!!Households!!Estimate  \
# 2                           7.6%                         4.4%
# 3                           5.2%                         2.5%
# 4                           9.3%                         5.4%
# 5                           8.6%                         5.3%
# 6                          12.0%                         9.1%
# 7                          16.7%                        15.8%
# 8                          12.6%                        13.2%
# 9                          14.9%                        21.8%
# 10                          6.4%                        11.1%
# 11                          6.7%                        11.4%
# 12                        59,674                       88,121
# 13                        82,956                      109,524
# 14
# 15                         38.9%                        35.9%
# 16                           (X)                          (X)
# 17                           (X)                          (X)
#
#    Arizona!!Households!!Estimate Arkansas!!Households!!Estimate  \
# 2                           5.4%                           7.3%
# 3                           3.0%                           5.9%
# 4                           6.2%                           9.5%
# 5                           7.3%                           9.1%
# 6                          11.0%                          13.5%
# 7                          17.3%                          18.1%
# 8                          13.8%                          12.6%
# 9                          17.8%                          13.4%
# 10                          8.6%                           5.1%
# 11                          9.6%                           5.5%
# 12                        74,568                         55,432
# 13                       101,316                         76,853
# 14
# 15                         38.9%                          38.4%
# 16                           (X)                            (X)
# 17                           (X)                            (X)
#
#    California!!Households!!Estimate Colorado!!Households!!Estimate  \
# 2                              4.8%                           4.1%
# 3                              3.2%                           2.5%
# 4                              5.5%                           5.4%
# 5                              5.9%                           5.8%
# 6                              8.5%                           9.2%
# 7                             13.8%                          15.1%
# 8                             12.0%                          13.4%
# 9                             17.6%                          19.0%
# 10                            10.6%                          10.7%
# 11                            18.0%                          14.7%
# 12                           91,551                         89,302
# 13                          131,504                        119,039
# 14
# 15                            39.9%                          34.0%
# 16                              (X)                            (X)
# 17                              (X)                            (X)
#
#    Connecticut!!Households!!Estimate Delaware!!Households!!Estimate  \
# 2                               5.1%                           4.0%
# 3                               3.2%                           2.6%
# 4                               5.9%                           5.8%
# 5                               6.0%                           7.1%
# 6                               8.7%                          10.4%
# 7                              13.8%                          15.9%
# 8                              12.6%                          13.9%
# 9                              17.7%                          20.0%
# 10                             10.8%                           9.4%
# 11                             16.3%                          10.8%
# 12                            88,429                         82,174
# 13                           128,160                        105,438
# 14
# 15                             39.0%                          35.4%
# 16                               (X)                            (X)
# 17                               (X)                            (X)
#
#    District of Columbia!!Households!!Estimate Florida!!Households!!Estimate  \
# 2                                        6.8%                          5.6%
# 3                                        2.8%                          3.5%
# 4                                        5.1%                          7.2%
# 5                                        4.6%                          8.0%
# 6                                        7.0%                         11.7%
# 7                                       12.3%                         17.4%
# 8                                       10.7%                         13.4%
# 9                                       16.6%                         16.0%
# 10                                      10.3%                          7.7%
# 11                                      23.7%                          9.5%
# 12                                    101,027                        69,303
# 13                                    148,872                        99,349
# 14
# 15                                      30.6%                         38.2%
# 16                                        (X)                           (X)
# 17                                        (X)                           (X)
#
#     ... South Dakota!!Households!!Estimate Tennessee!!Households!!Estimate  \
# 2   ...                               5.0%                            5.4%
# 3   ...                               3.8%                            4.3%
# 4   ...                               7.3%                            7.8%
# 5   ...                               7.5%                            8.2%
# 6   ...                              11.5%                           12.6%
# 7   ...                              18.4%                           18.0%
# 8   ...                              14.3%                           13.3%
# 9   ...                              18.2%                           15.7%
# 10  ...                               7.1%                            7.2%
# 11  ...                               6.9%                            7.5%
# 12  ...                             69,728                          65,254
# 13  ...                             90,806                          89,799
# 14  ...
# 15  ...                              32.8%                           38.5%
# 16  ...                                (X)                             (X)
# 17  ...                                (X)                             (X)
#
#    Texas!!Households!!Estimate Utah!!Households!!Estimate  \
# 2                         5.5%                       3.0%
# 3                         3.6%                       2.4%
# 4                         6.6%                       4.1%
# 5                         7.8%                       5.9%
# 6                        11.0%                       9.1%
# 7                        17.1%                      17.0%
# 8                        12.8%                      14.4%
# 9                        16.2%                      21.0%
# 10                        8.7%                      11.2%
# 11                       10.7%                      11.9%
# 12                      72,284                     89,168
# 13                     101,738                    114,044
# 14
# 15                       37.8%                      34.2%
# 16                         (X)                        (X)
# 17                         (X)                        (X)
#
#    Vermont!!Households!!Estimate Virginia!!Households!!Estimate  \
# 2                           4.0%                           4.9%
# 3                           3.8%                           3.2%
# 4                           6.7%                           5.8%
# 5                           8.1%                           6.1%
# 6                          11.0%                           9.3%
# 7                          17.1%                          14.9%
# 8                          13.8%                          12.2%
# 9                          17.1%                          18.1%
# 10                          9.9%                          10.3%
# 11                          8.5%                          15.4%
# 12                        73,991                         85,873
# 13                        97,261                        119,058
# 14
# 15                         32.5%                          37.2%
# 16                           (X)                            (X)
# 17                           (X)                            (X)
#
#    Washington!!Households!!Estimate West Virginia!!Households!!Estimate  \
# 2                              4.5%                                7.1%
# 3                              2.8%                                6.3%
# 4                              4.9%                               10.5%
# 5                              5.4%                                9.9%
# 6                              8.8%                               12.5%
# 7                             14.7%                               17.4%
# 8                             13.1%                               12.2%
# 9                             18.9%                               14.2%
# 10                            10.5%                                5.1%
# 11                            16.2%                                4.8%
# 12                           91,306                              54,329
# 13                          125,847                              75,265
# 14
# 15                            33.3%                               34.2%
# 16                              (X)                                 (X)
# 17                              (X)                                 (X)
#
#    Wisconsin!!Households!!Estimate Wyoming!!Households!!Estimate
# 2                             4.6%                          5.2%
# 3                             3.5%                          3.4%
# 4                             7.0%                          7.5%
# 5                             7.4%                          8.2%
# 6                            12.0%                         11.3%
# 7                            18.1%                         17.7%
# 8                            13.7%                         13.8%
# 9                            18.1%                         18.7%
# 10                            8.0%                          7.6%
# 11                            7.6%                          6.6%
# 12                          70,996                        70,042
# 13                          94,085                        90,018
# 14
# 15                           32.1%                         32.8%
# 16                             (X)                           (X)
# 17                             (X)                           (X)
#
# [16 rows x 51 columns]
